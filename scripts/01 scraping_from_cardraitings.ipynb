# %% [markdown]
# # A Python bases script to read in credit card reviews from `cardraitings.com`, collect reward information from those credit cards, and try to find the best combination of cards for an individual's expenses

# %%
import os
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re
import pickle

# %%
# Opening us the website that contains links to reviews for 
# the cedit cards we will be investiating

parent_url = 'https://www.cardratings.com/credit-card-list.html'
res = requests.get(parent_url)
html_page = res.content
soup = BeautifulSoup(html_page, 'html.parser')
cc_urls = []
for link in soup.find_all('a', href=True):
    if 'cardratings.com/credit-card/' in link.get('href'):
        print(link.get('href'))
        cc_urls.append(link.get('href'))
# Out:
# https://www.cardratings.com/credit-card/aboc-platinum-rewards-credit-card.html
# https://www.cardratings.com/credit-card/aer-lingus-visa-signature-card.html
# https://www.cardratings.com/credit-card/american-airlines-aadvantage-mileup-card.html
# https://www.cardratings.com/credit-card/aaa-member-rewards-visa-signature-card.html
# https://www.cardratings.com/credit-card/aacs-american-association-of-christian-schools-visa-credit-card-review
# https://www.cardratings.com/credit-card/aarp-visa-signature-card.html
# https://www.cardratings.com/credit-card/aeo-inc.-credit-card.html
# https://www.cardratings.com/credit-card/aeo-inc-visa-card
# https://www.cardratings.com/credit-card/abercrombie-fitch-credit-card
# https://www.cardratings.com/credit-card/afcu-agriculture-federal-credit-union-secured-visa-classic
# https://www.cardratings.com/credit-card/afcu-agriculture-federal-credit-union-visa-classic
# https://www.cardratings.com/credit-card/afcu-agriculture-federal-credit-union-visa-platinum-no-rebates.html
# https://www.cardratings.com/credit-card/afcu-agriculture-federal-credit-union-visa-platinum
# https://www.cardratings.com/credit-card/air-force-federal-credit-union-platinum-visa
# https://www.cardratings.com/credit-card/allegiant-world-mastercard-review
# https://www.cardratings.com/credit-card/amtrust-bank-american-express-silver-card.html
# https://www.cardratings.com/credit-card/amtrust-bank-platinum-edition-visa-card.html
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-personal-gold-plus
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-gold-secured
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-personal-standard-plus
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-standard-secured
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-union
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-union-plus
# https://www.cardratings.com/credit-card/amazon-prime-rewards-visa-signature-card-review
# https://www.cardratings.com/credit-card/amazon-rewards-visa-signature-card
# https://www.cardratings.com/credit-card/americas-first-fcu-indie-visa.html
# https://www.cardratings.com/credit-card/americas-first-fcu-platinum-visa.html
# https://www.cardratings.com/credit-card/americas-first-fcu-visa-platinum-plus.html
# https://www.cardratings.com/credit-card/americas-first-fcu-visa-platinum-pro
# https://www.cardratings.com/credit-card/americas-first-fcu-visa-secured.html
# https://www.cardratings.com/credit-card/american-airlines-aadvantage-aviator-business-mastercard-review
# https://www.cardratings.com/credit-card/american-airlines-aadvantage-aviator-red-world-elite-mastercard-review
# https://www.cardratings.com/credit-card/american-savings-bank-2%-unlimited-cash-back-business-rewards-visa-card.html
# https://www.cardratings.com/credit-card/american-savings-bank-2%-unlimited-cash-back-visa-card-review
# https://www.cardratings.com/credit-card/american-savings-bank-business-edition-secured-visa-card-review
# https://www.cardratings.com/credit-card/american-savings-bank-business-edition-visa-card.html
# https://www.cardratings.com/credit-card/amrican-savings-bank-business-edition-visa-card-with-reward-simplicity-review
# https://www.cardratings.com/credit-card/american-savings-bank-complete-rewards-visa-card.html
# https://www.cardratings.com/credit-card/american-savings-bank-platinum-edition-visa-card.html
# https://www.cardratings.com/credit-card/american-savings-bank-secured-visa-card.html
# https://www.cardratings.com/credit-card/amtrak-guest-rewards-world-mastercard-credit-card-review
# https://www.cardratings.com/credit-card/amtrust-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/the-animal-friends-visa-platinum-rewards-card
# https://www.cardratings.com/credit-card/ann-taylor-credit-card
# https://www.cardratings.com/credit-card/ann-taylor-mastercard
# https://www.cardratings.com/credit-card/anvil-brand-visa-credit-card-review
# https://www.cardratings.com/credit-card/applied-bank-secured-visa-credit-card.html
# https://www.cardratings.com/credit-card/arbor-day-foundation-rewards-visa-card-review
# https://www.cardratings.com/credit-card/arizona-cardinals-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/arizona-diamondbacks-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/armed-forced-bank-credit-builder-secured-visa-credit-card.html
# https://www.cardratings.com/credit-card/armed-forces-bank-visa-gold-credit-card
# https://www.cardratings.com/credit-card/arvest-corporate-visa-card
# https://www.cardratings.com/credit-card/arvest-elite-purchasing-visa-card
# https://www.cardratings.com/credit-card/arvest-visa-card
# https://www.cardratings.com/credit-card/arvest-visa-gold-card
# https://www.cardratings.com/credit-card/arvest-visa-platinum-card
# https://www.cardratings.com/credit-card/ashley-stewart-credit-card
# https://www.cardratings.com/credit-card/associated-bank-american-express-cash-rewards-credit-card-review
# https://www.cardratings.com/credit-card/associated-bank-american-express-premier-rewards-card-review
# https://www.cardratings.com/credit-card/associated-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/associated-bank-visa-platinum-business-real-rewards-card
# https://www.cardratings.com/credit-card/associated-bank-visa-business-rewards-plus-card
# https://www.cardratings.com/credit-card/associated-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/associated-bank-visa-secured-card
# https://www.cardratings.com/credit-card/associated-bank-visa-signature-card
# https://www.cardratings.com/credit-card/atlanta-braves-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/atlanta-falcons-nfl-extra-points-visa-card-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/british-airways-visa-signature-card.html
# https://www.cardratings.com/credit-card/bamsl-visa-signature-rewards-card-review
# https://www.cardratings.com/credit-card/bbt-bright-card.html
# https://www.cardratings.com/credit-card/bbt-bright-secured-credit-card-review
# https://www.cardratings.com/credit-card/bbt-bright-for-business-credit-card-review
# https://www.cardratings.com/credit-card/bbt-cash-rewards-secured-credit-card-review
# https://www.cardratings.com/credit-card/bbt-spectrum-rewards-card.html
# https://www.cardratings.com/credit-card/bbt-spectrum-cash-rewards-for-business-credit-card-review
# https://www.cardratings.com/credit-card/bbt-spectrum-travel-rewards-credit-card-review
# https://www.cardratings.com/credit-card/bbt-spectrum-travel-rewards-for-business-credit-card-review
# https://www.cardratings.com/credit-card/bbttravel-rewards-secured-credit-card-review
# https://www.cardratings.com/credit-card/bbt-vantage-visa-signature-credit-card-review
# https://www.cardratings.com/credit-card/bbva-clearpoints-credit-card-review
# https://www.cardratings.com/credit-card/bbva-optimizer-credit-card-review
# https://www.cardratings.com/credit-card/bbva-rewards-card-review
# https://www.cardratings.com/credit-card/bbva-secured-visa-business-credit-card-review
# https://www.cardratings.com/credit-card/bbva-select-credit-card-review
# https://www.cardratings.com/credit-card/bbva-visa-business-rewards-credit-card-review
# https://www.cardratings.com/credit-card/bmo-harris-bank-business-platinum-mastercard-credit-card-review
# https://www.cardratings.com/credit-card/bmo-harris-bank-business-platinum-rewards-mastercard-credit-card-review
# https://www.cardratings.com/credit-card/bmo-harris-bank-cash-back-mastercard-review
# https://www.cardratings.com/credit-card/bmo-harris-bank-platinum-rewards-mastercard-review
# https://www.cardratings.com/credit-card/bmo-harris-bank-premium-rewards-mastercard-review
# https://www.cardratings.com/credit-card/bmw-card-review
# https://www.cardratings.com/credit-card/bmw-precision-card-review
# https://www.cardratings.com/credit-card/btc-bank-visa-credit-card-review
# https://www.cardratings.com/credit-card/ballston-spa-national-bank-cash-rewards-platinum-card-review
# https://www.cardratings.com/credit-card/ballston-spa-natl-bank-visa-platinum-credit-card.html
# https://www.cardratings.com/credit-card/ballston-spa-national-bank-visa-small-business-cash-rewards-card--review
# https://www.cardratings.com/credit-card/ballston-spa-national-bank-visa-small-business-edition-card-review
# https://www.cardratings.com/credit-card/ballston-spa-national-bank-visa-small-business-rewards-card-review
# https://www.cardratings.com/credit-card/baltimore-orioles-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/baltimore-ravens-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/banana-republic-credit-card
# https://www.cardratings.com/credit-card/banana-republic-visa-card
# https://www.cardratings.com/credit-card/bangor-savings-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/bangor-savings-bank-college-rewards-visa-card
# https://www.cardratings.com/credit-card/bangor-savings-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/bangor-savings-bank-secured-visa-card.html
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-signature-card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-business-card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-business-travel-card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-platinum-business-rewards-card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/bank-of-america-cash-rewards-for-students.html
# https://www.cardratings.com/credit-card/bank-of-america-travel-rewards-credit-card-for-students
# https://www.cardratings.com/credit-card/bank-of-oklahoma-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-secured-visa-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-real-rewards-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-business-card-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-business-real-rewards-card-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-college-real-rewards-review
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-platinum-card-review
# https://www.cardratings.com/credit-card/bank-of-the-west-business-mastercard-review
# https://www.cardratings.com/credit-card/bank-of-the-west-business-rewards-mastercard-review
# https://www.cardratings.com/credit-card/bank-of-the-west-cash-back-world-credit-card-review
# https://www.cardratings.com/credit-card/bank-of-the-west-platinum-credit-card-review
# https://www.cardratings.com/credit-card/bank-of-the-west-secured-credit-card-review
# https://www.cardratings.com/credit-card/bankamericard-credit-card-for-students.html
# https://www.cardratings.com/credit-card/barclaycard-financing-visa-card.html
# https://www.cardratings.com/credit-card/barnes-noble-mastercard
# https://www.cardratings.com/credit-card/bealls-florida-credit-card
# https://www.cardratings.com/credit-card/belk-rewards-card
# https://www.cardratings.com/credit-card/berkshire-bank-cash-rewards-american-express-card.html
# https://www.cardratings.com/credit-card/berkshire-bank-premier-rewards-american-express-card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-secured-visa-card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-college-rewards-visa-card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-signature-card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-business-card
# https://www.cardratings.com/credit-card/berkshire-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-platinum-business-rewards-card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-business-travel-card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/bethpage-fcu-mastercard-platinum-rewards-credit-card.html
# https://www.cardratings.com/credit-card/bethpage-fcu-mastercard-cash-back-credit-card.html
# https://www.cardratings.com/credit-card/bethpage-fcu-mastercard-low-rate-credit-card.html
# https://www.cardratings.com/credit-card/bloomingdales-american-express-card-review
# https://www.cardratings.com/credit-card/bloomingdales-credit-card
# https://www.cardratings.com/credit-card/boston-red-sox-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/bremer-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/bremer-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/bremer-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/bremer-bank-visa-business-real-rewards-card-review
# https://www.cardratings.com/credit-card/bremer-bank-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/bremer-bank-visa-college-rewards-card-review
# https://www.cardratings.com/credit-card/bremer-bank-visa-platinum-card-review
# https://www.cardratings.com/credit-card/bremer-bank-visa-real-rewards-card-review
# https://www.cardratings.com/credit-card/bremer-bank-visa-secured-card-review
# https://www.cardratings.com/credit-card/bryant-university-alumni-visa-rewards-card-review
# https://www.cardratings.com/credit-card/brylanehome-credit-card
# https://www.cardratings.com/credit-card/buffalo-bills-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/synchrony-care-credit-card.html
# https://www.cardratings.com/credit-card/chase-freedom-unlimited.html
# https://www.cardratings.com/credit-card/chase-sapphire-reserve.html
# https://www.cardratings.com/credit-card/citi-rewards-plus-card.html
# https://www.cardratings.com/credit-card/citi-aadvantage-executive-world-elite-mastercard.html
# https://www.cardratings.com/credit-card/citi-aadvantage-platinum-select-mastercard.html
# https://www.cardratings.com/credit-card/citi-diamond-preferred-card
# https://www.cardratings.com/credit-card/citi-double-cash-card.html
# https://www.cardratings.com/credit-card/citibusiness-aadvantage-platinum-select-mastercard.html
# https://www.cardratings.com/credit-card/costco-anywhere-visa-card-by-citi.html
# https://www.cardratings.com/credit-card/credit-one-bank-visa-credit-card.html
# https://www.cardratings.com/credit-card/ccsu-alumni-rewards-visa-card-review
# https://www.cardratings.com/credit-card/cfcu-visa-classic.html
# https://www.cardratings.com/credit-card/cfcu-credit-union-classic-visa
# https://www.cardratings.com/credit-card/cfcu-credit-union-platunum-visa
# https://www.cardratings.com/credit-card/cfcu-rewards-visa-card.html
# https://www.cardratings.com/credit-card/cfcu-credit-union-secured-classic-plus-visa
# https://www.cardratings.com/credit-card/cabelas-club-mastercard-review
# https://www.cardratings.com/credit-card/carcareone-credit-card--review
# https://www.cardratings.com/credit-card/carecredit-credit-card-review
# https://www.cardratings.com/credit-card/carnival-funpoints-world-mastercard
# https://www.cardratings.com/credit-card/carolina-panthers-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/catherines-credit-card
# https://www.cardratings.com/credit-card/celebrity-cruises-visa-signature-credit-card.html
# https://www.cardratings.com/credit-card/chemical-bank-maximum-rewards-card-review
# https://www.cardratings.com/credit-card/chemical-bank-platinum-edition-card-review
# https://www.cardratings.com/credit-card/chemical-bank-secured-visa-review
# https://www.cardratings.com/credit-card/chevron-and-texaco-credit-card-review
# https://www.cardratings.com/credit-card/chevron-and-texaco-visa-card-review
# https://www.cardratings.com/credit-card/chicago-bears-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/chicago-cubs-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/chicago-white-sox-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/choice-privileges-no-annual-fee-visa-signature-card-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/christopher-banks-credit-card-review
# https://www.cardratings.com/credit-card/cincinnati-bengals-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/cincinnati-reds-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/citizens-bank-business-platinum-mastercard-review
# https://www.cardratings.com/credit-card/citizens-bank-cash-back-plus-world-mastercard-review
# https://www.cardratings.com/credit-card/citizens-bank-clear-value-mastercard-review
# https://www.cardratings.com/credit-card/city-national-crystal-visa-rewards-card.html
# https://www.cardratings.com/credit-card/city-national-bank-visa-cash-back-signature-card-review
# https://www.cardratings.com/credit-card/city-national-bank-visa-platinum-credit-card-with-city-national-rewards
# https://www.cardratings.com/credit-card/city-national-bank-visa-signature-credit-card-with-city-national-rewards
# https://www.cardratings.com/credit-card/clark-crown-endless-rewards-mastercard-review
# https://www.cardratings.com/credit-card/cleveland-browns-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/cleveland-indians-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/colorado-rockies-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/columbia-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/columbia-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/columbia-bank-visa-signature-real-rewards-card-review
# https://www.cardratings.com/credit-card/columbia-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/columbia-bank-visa-business-real-rewards-card-review
# https://www.cardratings.com/credit-card/columbia-bank-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/columbia-bank-visa-college-real-rewards-review
# https://www.cardratings.com/credit-card/columbia-bank-visa-platinum-card-review
# https://www.cardratings.com/credit-card/columbia-bank-visa-secured-card-review
# https://www.cardratings.com/credit-card/commerce-bank-secured-visa-credit-card.html
# https://www.cardratings.com/credit-card/commerce-bank-special-connectionssm-mastercard-with-rewards.html
# https://www.cardratings.com/credit-card/commerce-bank-special-connections-visa-with-rewards
# https://www.cardratings.com/credit-card/commerce-bank-world-elite-mastercard.html
# https://www.cardratings.com/credit-card/commerce-bank-toggle-visa-signature-review
# https://www.cardratings.com/credit-card/crutchfield-credit-card-review
# https://www.cardratings.com/credit-card/deserve-edu.html
# https://www.cardratings.com/credit-card/dcu-visa-platinum-credit-card.html
# https://www.cardratings.com/credit-card/dcu-visa-platinum-rewards-credit-card.html
# https://www.cardratings.com/credit-card/dcu-visa-platinum-secured-credit-card.html
# https://www.cardratings.com/credit-card/dallas-cowboys-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/davids-bridal-credit-card-review
# https://www.cardratings.com/credit-card/denver-broncos-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/detroit-lions-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/detroit-tigers-major-league-baseball-extra-bases-credit-card
# https://www.cardratings.com/credit-card/diamond-resorts-international-mastercard.html
# https://www.cardratings.com/credit-card/dillons-bakers-gerbes-rewards-world-mastercard
# https://www.cardratings.com/credit-card/drury-gold-club-key-card.html
# https://www.cardratings.com/credit-card/esl-visa-business-card.html
# https://www.cardratings.com/credit-card/eastern-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/eastern-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/eastern-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/eastern-bank-visa-signature-college-real-rewards-card-review
# https://www.cardratings.com/credit-card/eastern-bank-visa-signature-real-rewards-card-review
# https://www.cardratings.com/credit-card/eastern-bank-visa-business-card-review
# https://www.cardratings.com/credit-card/eastern-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/eastern-bank-visa-business-real-rewards-card--review
# https://www.cardratings.com/credit-card/eastern-bank-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/eastern-bank-visa-platinum-card-review
# https://www.cardratings.com/credit-card/eddie-bauer-credit-card
# https://www.cardratings.com/credit-card/evans-bank-small-business-cash-rewards-card-review
# https://www.cardratings.com/credit-card/evans-visa-cash-rewards-platinum-credit-card-review
# https://www.cardratings.com/credit-card/evans-visa-platinum-edition-credit-card-review
# https://www.cardratings.com/credit-card/evans-visa-rewards-platinum-credit-card-review
# https://www.cardratings.com/credit-card/evans-visa-small-business-edition-review
# https://www.cardratings.com/credit-card/evans-visa-small-business-rewards-card-review
# https://www.cardratings.com/credit-card/everyday-points-business-mastercard-review
# https://www.cardratings.com/credit-card/express-credit-card
# https://www.cardratings.com/credit-card/first-access-visa-credit-card.html
# https://www.cardratings.com/credit-card/flw-fishing-league-worldwide-visa-rewards-card-review
# https://www.cardratings.com/credit-card/fna-florida-nurses-association-visa-rewards-review
# https://www.cardratings.com/credit-card/fop-fraternal-order-of-police-visa-rewards-credit-card-review
# https://www.cardratings.com/credit-card/family-handyman-mastercard-with-rewards-review
# https://www.cardratings.com/credit-card/fifth-third-secured-card-review
# https://www.cardratings.com/credit-card/fifth-third-business-rewards-mastercard-review
# https://www.cardratings.com/credit-card/fingerhut-credit-account.html
# https://www.cardratings.com/credit-card/first-citizens-business-visa-card-review
# https://www.cardratings.com/credit-card/first-citizens-rewards-business-visa-card-review
# https://www.cardratings.com/credit-card/first-citizens-rewards-visa-card-review
# https://www.cardratings.com/credit-card/first-citizens-rewards-visa-card-accelerate-your-earnings-review
# https://www.cardratings.com/credit-card/first-citizens-rewards-visa-with-unlimited-cash-back-review
# https://www.cardratings.com/credit-card/first-citizens-smart-option-visa-card-review
# https://www.cardratings.com/credit-card/first-command-bank-classic-visa-card
# https://www.cardratings.com/credit-card/first-command-bank-platinum-visa-card
# https://www.cardratings.com/credit-card/first-hawaiian-bank-business-mastercard.html
# https://www.cardratings.com/credit-card/first-hawaiian-bank-cash-rewards-business-credit-card.html
# https://www.cardratings.com/credit-card/first-hawaiian-bank-mastercard
# https://www.cardratings.com/credit-card/first-hawaiian-bank-priority-rewards-premier-world-elite-mastercard
# https://www.cardratings.com/credit-card/first-hawaiian-bank-priority-destinationssm-world-mastercard.html
# https://www.cardratings.com/credit-card/first-hawaiian-bank-priority-destinations-world-elite-business-mastercard.html
# https://www.cardratings.com/credit-card/first-hawaiian-bank-priority-rewards-business-credit-cardsm.html
# https://www.cardratings.com/credit-card/united-mileageplus-business-credit-card.html
# https://www.cardratings.com/credit-card/first-hawaiian-bank-united-mileageplus-credit-card
# https://www.cardratings.com/credit-card/first-horizon-platinum-premier-visa-card-review
# https://www.cardratings.com/credit-card/first-horizon-secured-visa-review
# https://www.cardratings.com/credit-card/first-horizon-visa-signature-review
# https://www.cardratings.com/credit-card/first-horizon-visa-classic-review
# https://www.cardratings.com/credit-card/first-internet-bank-of-indiana-cashback-credit-card-review
# https://www.cardratings.com/credit-card/connect-classic
# https://www.cardratings.com/credit-card/first-midwest-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-business-platinum-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-business-real-rewards-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-college-real-rewards-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-platinum-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-signature-real-rewards-card-review
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-secured-card-review
# https://www.cardratings.com/credit-card/bucksbacksm-platinum-edition-visa-card
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-business-edition-secured-visa-card-review
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-business-edition-visa-card.html
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-complete-rewards-platinum-edition-visa-card.html
# https://www.cardratings.com/credit-card/platinum-edition-visa-card
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-business-edition-visa-card-with-reward-simplicity-review
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-secured-visa-card.html
# https://www.cardratings.com/credit-card/firstrust-business-platinum-card-review
# https://www.cardratings.com/credit-card/firstrust-business-platinum-rewards-card-review
# https://www.cardratings.com/credit-card/firstrust-platinum-rewards-card-review
# https://www.cardratings.com/credit-card/firstrust-platinum-card-review
# https://www.cardratings.com/credit-card/five-star-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/five-star-bank-college-rewards-visa-card.html
# https://www.cardratings.com/credit-card/five-star-bank-travel-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/five-star-bank-secured-visa
# https://www.cardratings.com/credit-card/five-star-bank-visa-signature-bonus-rewards-card
# https://www.cardratings.com/credit-card/five-star-bank-visa-business-card
# https://www.cardratings.com/credit-card/five-star-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/five-star-bank-visa-business-bonus-rewards-card
# https://www.cardratings.com/credit-card/five-star-bank-visa-business-bonus-rewards-plus-card-review
# https://www.cardratings.com/credit-card/five-star-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/flagstar-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/flagstar-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/flagstar-bank-visa-real-rewards-card-review
# https://www.cardratings.com/credit-card/flagstar-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/flagstar-bank-visa-business-real-rewards-card-review
# https://www.cardratings.com/credit-card/flagstar-bank-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/flagstar-bank-visa-college-real-rewards-card-review
# https://www.cardratings.com/credit-card/flagstar-bank-visa-platinum-card-review
# https://www.cardratings.com/credit-card/flagstar-bank-visa-secured-card-review
# https://www.cardratings.com/credit-card/fred-meyer-rewards-visa-card
# https://www.cardratings.com/credit-card/frontier-airlines-world-mastercard
# https://www.cardratings.com/credit-card/frys-food-drug-stores-frys-marketplace-123-rewards-visa
# https://www.cardratings.com/credit-card/fulton-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/fulton-bank-college-rewards-visa-card.html
# https://www.cardratings.com/credit-card/fulton-bank-travel-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/fulton-bank-secured-visa-card.html
# https://www.cardratings.com/credit-card/fulton-bank-visa-business-card.html
# https://www.cardratings.com/credit-card/fulton-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/fulton-bank-visa-business-bonus-rewards-card.html
# https://www.cardratings.com/credit-card/fulton-bank-visa-business-bonus-rewards-plus-card.html
# https://www.cardratings.com/credit-card/fulton-bank-visa-platinum-card.html
# https://www.cardratings.com/credit-card/fulton-bank-visa-signature-bonus-rewards-plus-card.html
# https://www.cardratings.com/credit-card/garden-state-community-bank-graphitesm-american-express-card.html
# https://www.cardratings.com/credit-card/garden-state-community-bank-platinum-edition-visa-card.html
# https://www.cardratings.com/credit-card/garden-state-community-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/goody-s-credit-card
# https://www.cardratings.com/credit-card/gordmans-credit-card
# https://www.cardratings.com/credit-card/green-bay-packers-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/grossmans-bargain-outlet-credit-card-review
# https://www.cardratings.com/credit-card/the-guide-dogs-for-the-blind-visa-platinum-rewards-card
# https://www.cardratings.com/credit-card/hilton-honors-card-american-express-aspire-card.html
# https://www.cardratings.com/credit-card/hilton-honors-card-american-express.html
# https://www.cardratings.com/credit-card/hilton-honors-surpass-card.html
# https://www.cardratings.com/credit-card/hsbc-advance-mastercard-credit-card.html
# https://www.cardratings.com/credit-card/hsbc-cash-rewards-mastercard-credit-card-student-account-review
# https://www.cardratings.com/credit-card/hsbc-premier-world-elite-mastercard-credit-card-review
# https://www.cardratings.com/credit-card/hsbc-premier-world-mastercard
# https://www.cardratings.com/credit-card/harleydavidson-visa-signature-credit-card
# https://www.cardratings.com/credit-card/harleydavidson-visa-high-performance-credit-card
# https://www.cardratings.com/credit-card/harleydavidson-visa-secured-card
# https://www.cardratings.com/credit-card/harris-teeter-rewards-world-mastercard-review
# https://www.cardratings.com/credit-card/
# https://www.cardratings.com/credit-card/hawaiian-airlines-business-mastercard.html
# https://www.cardratings.com/credit-card/the-holland-america-line-rewards-visa-card
# https://www.cardratings.com/credit-card/homegoods-credit-card-review
# https://www.cardratings.com/credit-card/houston-astros-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/houston-texans-nfl-extra-points-from-barclays-bank-of-delaware
# https://www.cardratings.com/credit-card/ihg-rewards-club-premier-credit-card.html
# https://www.cardratings.com/credit-card/ihg-rewards-club-traveler-credit-card.html
# https://www.cardratings.com/credit-card/https://www.cardratings.com/iberia-visa-signature-card.html
# https://www.cardratings.com/credit-card/indianapolis-colts-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/jasper-card.html
# https://www.cardratings.com/credit-card/j-crew-credit-card
# https://www.cardratings.com/credit-card/j.-jill-credit-card-review
# https://www.cardratings.com/credit-card/jc-penney-credit-card-review
# https://www.cardratings.com/credit-card/jacksonville-jaguars-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/jeff-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/jeff-bank-college-rewards-visa-card
# https://www.cardratings.com/credit-card/jeff-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/jeff-bank-secured-visa-card
# https://www.cardratings.com/credit-card/jeff-bank-signature-visa-card
# https://www.cardratings.com/credit-card/jeff-bank-visa-business-card
# https://www.cardratings.com/credit-card/jeff-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/jeff-bank-visa-business-real-rewards-card
# https://www.cardratings.com/credit-card/jeff-bank-visa-business-travel-card
# https://www.cardratings.com/credit-card/jeff-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/jessica-london-credit-card
# https://www.cardratings.com/credit-card/jetblue-business-card-review
# https://www.cardratings.com/credit-card/justice-fcu-aca-american-correctional-association-visa-rewards-card-review
# https://www.cardratings.com/credit-card/justice-fcu-afna-visa-rewards-credit-card.html
# https://www.cardratings.com/credit-card/blue-knights-international-visa-rewards-card.html
# https://www.cardratings.com/credit-card/justice-fcu-fbi-leeda-visa-rewards-credit-card.html
# https://www.cardratings.com/credit-card/fbinaa-visa-rewards-credit-card.html
# https://www.cardratings.com/credit-card/justice-fcu-neia-visa-rewards-credit-card.html
# https://www.cardratings.com/credit-card/justice-fcu-nnalea-affinity-visa-credit-card.html
# https://www.cardratings.com/credit-card/justice-fcu-nsa-visa-rewards-credit-card.html
# https://www.cardratings.com/credit-card/justice-fcu-sfsafbi-visa-rewards-credit-card.html
# https://www.cardratings.com/credit-card/justice-federal-credit-union-secured-visa-classic-card
# https://www.cardratings.com/credit-card/justice-federal-credit-union-student-rewards-visa-card
# https://www.cardratings.com/credit-card/justice-federal-credit-union-visa-classic-card
# https://www.cardratings.com/credit-card/justice-federal-credit-union-visa-gold-card
# https://www.cardratings.com/credit-card/justice-federal-credit-union-visa-platinum-rewards-card
# https://www.cardratings.com/credit-card/kba-kansas-bar-association-visa-rewards-card-review
# https://www.cardratings.com/credit-card/kcmba-visa-signature-credit-card-review
# https://www.cardratings.com/credit-card/kansas-city-chiefs-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/kansas-city-royals-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/key-cashback-credit-card-review
# https://www.cardratings.com/credit-card/key-secured-credit-card-review
# https://www.cardratings.com/credit-card/keybank-business-mastercard-credit-card.html
# https://www.cardratings.com/credit-card/keybank-business-rewards-mastercard-credit-card.html
# https://www.cardratings.com/credit-card/key2more-rewards-mastercard-credit-card.html
# https://www.cardratings.com/credit-card/keybank-latitude-credit-card.html
# https://www.cardratings.com/credit-card/king-soopers-rewards-world-mastercard-review
# https://www.cardratings.com/credit-card/kingsize-credit-card
# https://www.cardratings.com/credit-card/kiwanis-visa-rewards-card-review
# https://www.cardratings.com/credit-card/kohls-charge-card
# https://www.cardratings.com/credit-card/korean-air-skypass-select-visa-signature-card
# https://www.cardratings.com/credit-card/korean-air-skypass-visa-business-card
# https://www.cardratings.com/credit-card/korean-air-skypass-visa-secured-card
# https://www.cardratings.com/credit-card/korean-air-skypass-visa-signature-credit-card
# https://www.cardratings.com/credit-card/korean-air-skyblue-skypass-visa-credit-card
# https://www.cardratings.com/credit-card/kroger-rewards-world-mastercard
# https://www.cardratings.com/credit-card/latam-visa-signature-card
# https://www.cardratings.com/credit-card/latam-visa-card
# https://www.cardratings.com/credit-card/latam-visa-secured-card
# https://www.cardratings.com/credit-card/lane-bryant-credit-card
# https://www.cardratings.com/credit-card/oakland-raiders-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/levin-furniture-credit-card-review
# https://www.cardratings.com/credit-card/lexus-pursuits-credit-card-review
# https://www.cardratings.com/credit-card/lexus-pursuits-visa-card-review
# https://www.cardratings.com/credit-card/los-angeles-angels-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/los-angeles-chargers-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/los-angeles-dodgers-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/los-angeles-rams-nfl-extra-points
# https://www.cardratings.com/credit-card/loft-credit-card-review
# https://www.cardratings.com/credit-card/loveloft-mastercard-review
# https://www.cardratings.com/credit-card/lufthansa-miles-more-world-mastercard
# https://www.cardratings.com/credit-card/lumber-liquidators-credit-card.html
# https://www.cardratings.com/credit-card/marriott-bonvoy-bold-credit-card.html
# https://www.cardratings.com/credit-card/marriott-bonvoy-boundless-visa-signature-credit-card.html
# https://www.cardratings.com/credit-card/mastercard-black-card.html
# https://www.cardratings.com/credit-card/mastercard-gold-card.html
# https://www.cardratings.com/credit-card/mastercard-titanium-card.html
# https://www.cardratings.com/credit-card/mt-visa-credit-card.html
# https://www.cardratings.com/credit-card/mt-visa-credit-card-with-rewards.html
# https://www.cardratings.com/credit-card/mt-visa-signature-credit-card.html
# https://www.cardratings.com/credit-card/mcu-secured-visa
# https://www.cardratings.com/credit-card/mcu-true-rewards-cash-backvisa-review
# https://www.cardratings.com/credit-card/mcu-visa-platinum
# https://www.cardratings.com/credit-card/major-league-baseball-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/msta-visa-rewards-credit-card-review
# https://www.cardratings.com/credit-card/macys-american-express-card.html
# https://www.cardratings.com/credit-card/macys-credit-card
# https://www.cardratings.com/credit-card/malvern-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/malvern-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/malvern-bank-secured-visa-card
# https://www.cardratings.com/credit-card/malvern-bank-visa-signature-real-rewards-card
# https://www.cardratings.com/credit-card/malvern-bank-visa-business-card
# https://www.cardratings.com/credit-card/malvern-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/malvern-bank-visa-business-real-rewards-card
# https://www.cardratings.com/credit-card/malvern-bank-visa-business-rewards-plus-card
# https://www.cardratings.com/credit-card/marshalls-credit-card-review
# https://www.cardratings.com/credit-card/mathis-brothers-furniture-credit-card-review
# https://www.cardratings.com/credit-card/mattress-firm-credit-card-review
# https://www.cardratings.com/credit-card/members-1st-federal-cu-visa-platinum-secured-card.html
# https://www.cardratings.com/credit-card/members-1st-fcu-visa-signature-rewards-credit-card.html
# https://www.cardratings.com/credit-card/members-1st-fcu-visa-platinum-low-rate-credit-card
# https://www.cardratings.com/credit-card/members-1st-fcu-visa-platinum-rewards-credit-card
# https://www.cardratings.com/credit-card/miami-dolphins-nfl-extra-points-f-rom-barclays-bank-delaware
# https://www.cardratings.com/credit-card/miami-marlins-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/michigan-tech-visa-rewards-card-review
# https://www.cardratings.com/credit-card/midfirst-bank-business-rewards-visa-credit-card-review
# https://www.cardratings.com/credit-card/midfirst-bank-business-secured-visa-card-review
# https://www.cardratings.com/credit-card/midfirst-bank-business-visa-credit-card-review
# https://www.cardratings.com/credit-card/midfirst-bank-rewards-credit-card-review
# https://www.cardratings.com/credit-card/midfirst-bank-secured-visa-credit-card-review
# https://www.cardratings.com/credit-card/midfirst-bank-visa-platinum-credit-card-review
# https://www.cardratings.com/credit-card/milwaukee-brewers-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/minnesota-twins-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/minnesota-vikings-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/murray-state-visa-rewards-card-review
# https://www.cardratings.com/credit-card/nasa-federal-visa-classic-review
# https://www.cardratings.com/credit-card/nasa-federal-visa-platinum-advantage-rewards-review
# https://www.cardratings.com/credit-card/nasa-federal-visa-platinum-cash-rewards
# https://www.cardratings.com/credit-card/nasa-federal-visa-star-trek-credit-cards-review
# https://www.cardratings.com/credit-card/nasw-visa-rewards-credit-card-review
# https://www.cardratings.com/credit-card/nbt-bank-cash-rewards-american-express-card.html
# https://www.cardratings.com/credit-card/alliance-bank-college-rewards-visa-card
# https://www.cardratings.com/credit-card/nbt-bank-travel-rewards-american-express-card.html
# https://www.cardratings.com/credit-card/alliance-bank-visa-signature-card
# https://www.cardratings.com/credit-card/alliance-bank-visa-business-card
# https://www.cardratings.com/credit-card/nbt-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/alliance-bank-visa-platinum-business-rewards-card
# https://www.cardratings.com/credit-card/alliance-bank-visa-business-travel-card
# https://www.cardratings.com/credit-card/NBT-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/alliance-bank-visa-secured-card
# https://www.cardratings.com/credit-card/ndsu-visa-rewards-credit-card-review
# https://www.cardratings.com/credit-card/nwtf-rewards-visa-credit-card-review
# https://www.cardratings.com/credit-card/new-york-community-bank-2%-cash-back-visa-card.html
# https://www.cardratings.com/credit-card/new-york-community-bank-platinum-edition-visa-card.html
# https://www.cardratings.com/credit-card/new-york-community-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/the-national-hot-rod-association-visa-platinum-rewards-card.html
# https://www.cardratings.com/credit-card/navy-fcu-go-rewards-credit-card-review
# https://www.cardratings.com/credit-card/navy-federal-more-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/navy-federal-platinum-credit-card-review
# https://www.cardratings.com/credit-card/navy-federal-visa-signature-flagship-rewards-credit-card-review
# https://www.cardratings.com/credit-card/navy-federal-cashrewards-credit-card-review
# https://www.cardratings.com/credit-card/navy-federal-nrewards-secured-credit-card-review
# https://www.cardratings.com/credit-card/new-england-patriots-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/new-orleans-saints-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/new-york-company-credit-card
# https://www.cardratings.com/credit-card/new-york-giants-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/new-york-jets-extra-points-visa-card
# https://www.cardratings.com/credit-card/new-york-mets-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/new-york-yankees-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/norwegian-cruise-line-world-mastercard-credit-card.html
# https://www.cardratings.com/credit-card/oakland-athletics-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/ohio-savings-bank-2%-cash-back-visa-card.html
# https://www.cardratings.com/credit-card/ohio-savings-bank-platinum-edition-visa-card.html
# https://www.cardratings.com/credit-card/ohio-savings-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/opus-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/opus-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/opus-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/opus-bank-visa-signature-real-rewards-card-review
# https://www.cardratings.com/credit-card/opus-bank-visa-business-card-review
# https://www.cardratings.com/credit-card/opus-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/opus-bank-visa-business-real-rewards-card-review
# https://www.cardratings.com/credit-card/opus-bank-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/opus-bank-visa-college-rewards-card-review
# https://www.cardratings.com/credit-card/opus-bank-visa-platinum-card-review
# https://www.cardratings.com/credit-card/penfed-visa-gold-review.html
# https://www.cardratings.com/credit-card/penfed-platinum-rewards-card
# https://www.cardratings.com/credit-card/penfed-power-cash-rewards-visa-signature-card.html
# https://www.cardratings.com/credit-card/p.c.-richard-son-credit-card-review
# https://www.cardratings.com/credit-card/pnc-pnc-cash-rewards-visa-signature-business-card-review
# https://www.cardratings.com/credit-card/pnc-cash-rewards-visa-credit-card
# https://www.cardratings.com/credit-card/pnc-core-visa-credit-card-review
# https://www.cardratings.com/credit-card/pnc-bank-travel-rewards-visa-business-credit-card.html
# https://www.cardratings.com/credit-card/pnc-bank-visa-signature-businessoptionssm-card.html
# https://www.cardratings.com/credit-card/pnc-bank-visa-business-credit-card.html
# https://www.cardratings.com/credit-card/pnc-bank-points-visa-business-credit-card.html
# https://www.cardratings.com/credit-card/pnc-points-visa-credit-card
# https://www.cardratings.com/credit-card/pnc-premier-traveler-visa-signature-credit-card-review
# https://www.cardratings.com/credit-card/palais-royal-credit-card
# https://www.cardratings.com/credit-card/the-pancreatic-cancer-action-network-visa-platinum-rewards-card
# https://www.cardratings.com/credit-card/partners-1st-fcu-visa-platinum-rewards-review
# https://www.cardratings.com/credit-card/partners-1st-fcu-visa-platinum-review
# https://www.cardratings.com/credit-card/pearle-vision-credit-card-review
# https://www.cardratings.com/credit-card/peebles-credit-card
# https://www.cardratings.com/credit-card/peoples-united-bank-mastercard-bonus-rewards-card-review
# https://www.cardratings.com/credit-card/peoples-united-bank-mastercard-platinum-review
# https://www.cardratings.com/credit-card/peoples-united-bank-travel-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/phi-kappa-phi-rewards-visa-credit-card-review
# https://www.cardratings.com/credit-card/philadelphia-eagles-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/philadelphia-phillies-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/picknsave-metro-market-rewards-world-mastercard
# https://www.cardratings.com/credit-card/pier-1-imports-rewards-credit-card-review
# https://www.cardratings.com/credit-card/pittsburgh-pirates-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/pittsburgh-steelers-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/plains-commerce-bank-mastercard-classic.html
# https://www.cardratings.com/credit-card/plains-commerce-bank-visa-classic
# https://www.cardratings.com/credit-card/plains-commerce-bank-visa-gold-card
# https://www.cardratings.com/credit-card/popular-bank-platinum-mastercard-review
# https://www.cardratings.com/credit-card/popular-bank-preferred-world-mastercard-review
# https://www.cardratings.com/credit-card/popular-bank-rewards-mastercard-review
# ...
# https://www.cardratings.com/credit-card/riverview-community-bank-visa-business-card
# https://www.cardratings.com/credit-card/riverview-community-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/riverview-community-bank-visa-platinum-business-rewards-card
# https://www.cardratings.com/credit-card/riverview-community-bank-visa-business-travel-card
# https://www.cardratings.com/credit-card/riverview-community-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/royal-caribbean-visa-signature-card.html
# https://www.cardratings.com/credit-card/simmons-bank-visa-platinum-rewards.html
# https://www.cardratings.com/credit-card/simmons-bank-platinum-visa
# https://www.cardratings.com/credit-card/southwest-airlines-rapid-rewards-plus-credit-card.html
# https://www.cardratings.com/credit-card/southwest-airlines-rapid-rewards-priority-credit-card.html
# https://www.cardratings.com/credit-card/southwest-airlines-rapid-rewards-premier-credit-card.html
# https://www.cardratings.com/credit-card/surge-mastercard-credit-card.html
# https://www.cardratings.com/credit-card/synchrony-car-care-credit-card.html
# https://www.cardratings.com/credit-card/sefcu-lightning-mastercard-review
# https://www.cardratings.com/credit-card/sefcu-mastercard-review
# https://www.cardratings.com/credit-card/sefcu-world-mastercard-review
# https://www.cardratings.com/credit-card/siu-southern-illinois-university-rewards-visa-credit-card-review
# https://www.cardratings.com/credit-card/smu-southern-methodist-university-visa-signature-rewards-credit-card-review
# https://www.cardratings.com/credit-card/san-diego-padres-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/san-francisco-49ers-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/san-francisco-giants-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/save-the-children-visa-signature-credit-card-review
# https://www.cardratings.com/credit-card/seattle-mariners-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/seattle-seahawks-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/seattle-u-visa-rewards-review
# https://www.cardratings.com/credit-card/rbc-visa-platinum-rewards
# https://www.cardratings.com/credit-card/smiths-food-drug-stores-123-rewards-visa
# https://www.cardratings.com/credit-card/solvay-bank-visa-business-card--review
# https://www.cardratings.com/credit-card/solvay-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/solvay-bank-visa-platinum-standard-card-review
# https://www.cardratings.com/credit-card/sons-of-italy-visa-rewards-review
# https://www.cardratings.com/credit-card/south-alabama-jaguars-visa-rewards-card-review
# https://www.cardratings.com/credit-card/southwestern-oklahoma-state-university-alumni-rewards-visa-card-review
# https://www.cardratings.com/credit-card/spirit-airlines-world-mastercard-credit-card.html
# https://www.cardratings.com/credit-card/st-louis-cardinals-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/stage-credit-card-review
# https://www.cardratings.com/credit-card/stand-up-to-cancer-credit-card-review
# https://www.cardratings.com/credit-card/staples-business-credit-cardrevolving
# https://www.cardratings.com/credit-card/starbucks-rewards-card
# https://www.cardratings.com/credit-card/state-farm-bank-visa-business-card
# https://www.cardratings.com/credit-card/state-farm-bank-good-neighbor-visa-credit-card
# https://www.cardratings.com/credit-card/state-farm-rewards-visa-credit-card
# https://www.cardratings.com/credit-card/state-farm-student-visa-credit-card
# https://www.cardratings.com/credit-card/stein-mart-credit-card.html
# https://www.cardratings.com/credit-card/stein-mart-platinum-mastercard-.html
# https://www.cardratings.com/credit-card/stephen-f.-austin-alumni-mastercard-rewards-card-review
# https://www.cardratings.com/credit-card/steuben-trust-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/steuben-trust-college-rewards-visa-card
# https://www.cardratings.com/credit-card/steuben-trust-travel-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/steuben-trust-business-card-visa-card
# https://www.cardratings.com/credit-card/steuben-trust-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/steuben-trust-visa-platinum-business-rewards-card
# https://www.cardratings.com/credit-card/steuben-trust-business-travel-card-visa-card
# https://www.cardratings.com/credit-card/steuben-trust-visa-platinum-card
# https://www.cardratings.com/credit-card/suntrust-business-rewards-credit-card-review
# https://www.cardratings.com/credit-card/suntrust-platinum-visa-with-cash-rewards
# https://www.cardratings.com/credit-card/suntrust-secured-credit-card.html
# https://www.cardratings.com/credit-card/synovus-business-travel-rewards-visa-credit-card-review
# https://www.cardratings.com/credit-card/synovus-business-visa-credit-card.html
# https://www.cardratings.com/credit-card/synovus-cash-rewards-visa-credit-card
# https://www.cardratings.com/credit-card/synovus-classic-visa-credit-card-review
# https://www.cardratings.com/credit-card/synovus-business-mastercard.html
# https://www.cardratings.com/credit-card/synovus-rewards-visa-credit-card
# https://www.cardratings.com/credit-card/synovus-travel-rewards-visa-credit-card-review
# https://www.cardratings.com/credit-card/td-cash-visa-credit-card
# https://www.cardratings.com/credit-card/hilton-honors-business-card-from-american-express-open.html
# https://www.cardratings.com/credit-card/the-world-of-hyatt-credit-card-from-chase.html
# https://www.cardratings.com/credit-card/total-visa-unsecured-credit-card.html
# https://www.cardratings.com/credit-card/tcf-bank-business-edition-secured-visa-card-review
# https://www.cardratings.com/credit-card/tcf-bank-business-edition-visa-card-review
# https://www.cardratings.com/credit-card/tcf-bank-business-edition-visa-card-with-reward-simplicity-review
# https://www.cardratings.com/credit-card/tcf-bank-maximum-rewards-visa-card-review
# https://www.cardratings.com/credit-card/tcf-bank-platinum-edition-visa-card-review
# https://www.cardratings.com/credit-card/tcf-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/td-ameritrade-client-rewards-credit-card-review
# https://www.cardratings.com/credit-card/td-business-solutions-visa-credit-card.html
# https://www.cardratings.com/credit-card/td-first-class-sm-visa-signature-credit-card.html
# https://www.cardratings.com/credit-card/tj-maxx-credit-card-review
# https://www.cardratings.com/credit-card/tjx-rewards-credit-card
# https://www.cardratings.com/credit-card/tjx-rewards-platinum-mastercard.html
# https://www.cardratings.com/credit-card/tna-tennessee-nurses-association-visa-rewards-review
# https://www.cardratings.com/credit-card/trio-preferred-credit-card
# https://www.cardratings.com/credit-card/talbots-classic-awards-platinum-credit-card.html
# https://www.cardratings.com/credit-card/tampa-bay-buccaneers-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/tampa-bay-rays-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/taste-of-home-mastercard-with-rewards-review
# https://www.cardratings.com/credit-card/teachers-fcu-business-credit-card-review
# https://www.cardratings.com/credit-card/tennessee-titans-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/tennis-express-rewards-visa-credit-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-signature-college-real-rewards-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-signature-real-rewards-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-business-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-business-real-rewards-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-platinum-card-review
# https://www.cardratings.com/credit-card/texas-rangers-bankamericard-cash-rewards-mastercard-.html
# https://www.cardratings.com/credit-card/texas-tech-mastercard-with-rewards-review
# https://www.cardratings.com/credit-card/the-brooks-brothers-card-review
# https://www.cardratings.com/credit-card/the-brooks-brothers-platinum-mastercard-review
# https://www.cardratings.com/credit-card/the-container-store-credit-card-review
# https://www.cardratings.com/credit-card/the-linux-foundation-visa-platinum-rewards-card
# https://www.cardratings.com/credit-card/tioga-state-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/tioga-state-bank-college-real-rewards-visa-card
# https://www.cardratings.com/credit-card/tioga-state-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/tioga-state-bank-secured-visa-card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-signature-real-rewards-card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-business-card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-business-real-rewards-card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-business-rewards-plus-card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-platinum-card
# https://www.cardratings.com/credit-card/tompkins-trust-company-cash-rewards-american-express-card.html
# https://www.cardratings.com/credit-card/
# https://www.cardratings.com/credit-card/tompkins-trust-company-premier-rewards-american-express-card-.html
# https://www.cardratings.com/credit-card/tompkins-trust-secured-visa-card
# https://www.cardratings.com/credit-card/tompkins-trust-company-visa-signature-real-rewards-card
# https://www.cardratings.com/credit-card/tompkins-trust-company-visa-business-card
# https://www.cardratings.com/credit-card/tompkins-trust-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/tompkins-trust-company-visa-platinum-business-rewards-cards
# https://www.cardratings.com/credit-card/tompkins-trust-company-visa-business-rewards-plus-card
# https://www.cardratings.com/credit-card/tompkins-trust-company-visaplatinum-card
# https://www.cardratings.com/credit-card/toronto-blue-jays-major-league-baseball-extra-bases-credit-card
# https://www.cardratings.com/credit-card/torrid-insider-credit-card.html
# https://www.cardratings.com/credit-card/toyota-rewards-visa-signature-card--review
# https://www.cardratings.com/credit-card/trek-credit-card.html
# https://www.cardratings.com/credit-card/tulsa-alumni-rewards-visa-card-review
# https://www.cardratings.com/credit-card/united-club-infinite-card
# https://www.cardratings.com/credit-card/united-explorer-card.html
# https://www.cardratings.com/credit-card/u.s.-pride-bankamericard-cash-rewards-visa-card.html
# https://www.cardratings.com/credit-card/ubs-visa-infinite-credit-card
# https://www.cardratings.com/credit-card/ubs-visa-signature-credit-card
# https://www.cardratings.com/credit-card/umb-direct-cash-visa-signature-credit-card-review
# https://www.cardratings.com/credit-card/umb-simply-rewardstm-visa-platinum-credit-card.html
# https://www.cardratings.com/credit-card/umsl-alumni-rewards-visa-card-review
# https://www.cardratings.com/credit-card/unt-north-texas-alumni-credit-card-with-rewards-review
# https://www.cardratings.com/credit-card/us-appliance-credit-card-review
# https://www.cardratings.com/credit-card/usa-volleyball-visa-signature-credit-card-review
# https://www.cardratings.com/credit-card/usaa-rewards-visa-signature-review
# https://www.cardratings.com/credit-card/uber-visa-credit-card-review
# https://www.cardratings.com/credit-card/union-bank-business-rewards-visa-credit-card-review
# https://www.cardratings.com/credit-card/union-bank-business-secured-visa-credit-card-review
# https://www.cardratings.com/credit-card/union-bank-business-visa-credit-card-review
# https://www.cardratings.com/credit-card/union-bank-cashback-rewards-visa-card-review
# https://www.cardratings.com/credit-card/union-bank-rewards-visa-card-review
# https://www.cardratings.com/credit-card/union-bank-secured-visa-credit-card-review
# https://www.cardratings.com/credit-card/union-bank-travel-rewards-visa-card-review
# https://www.cardratings.com/credit-card/union-bank-visa-credit-card-review
# https://www.cardratings.com/credit-card/unfcu-visa-azure-credit-card.html
# https://www.cardratings.com/credit-card/united-nations-federal-credit-union-elite-credit-card
# https://www.cardratings.com/credit-card/montana-visa-rewards-credit-card-review
# https://www.cardratings.com/credit-card/upromise-mastercard.html
# https://www.cardratings.com/credit-card/valparaiso-alumni-visa-rewards-card-review
# https://www.cardratings.com/credit-card/value-city-furniture-credit-card-review
# https://www.cardratings.com/credit-card/victorias-secret-angel-credit-card
# https://www.cardratings.com/credit-card/virgin-atlantic-world-elite-mastercard.html
# https://www.cardratings.com/credit-card/washington-nationals-bankamericard-cash-rewards-mastercard
# https://www.cardratings.com/credit-card/washington-redskins-nfl-extra-points-from-barclays-bank-delaware
# https://www.cardratings.com/credit-card/webster-bank-cash-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/webster-bank-premier-rewards-american-express-card-review
# https://www.cardratings.com/credit-card/webster-bank-secured-visa-card-review
# https://www.cardratings.com/credit-card/webster-bank-visa-signature-college-real-rewards-card-review
# https://www.cardratings.com/credit-card/webster-bank-visa-signature-real-rewards-card-review
# https://www.cardratings.com/credit-card/webster-bank-visa-business-cash-card-review
# https://www.cardratings.com/credit-card/webster-bank-visa-business-platinum-card-review
# https://www.cardratings.com/credit-card/webster-bank-visa-business-real-rewards-card-review
# https://www.cardratings.com/credit-card/webster-bank-visa-business-rewards-plus-card-review
# https://www.cardratings.com/credit-card/webster-bank-visa-platinum-card-review
# https://www.cardratings.com/credit-card/wells-fargo-advisors-by-invitation-visa-signature-card.html
# https://www.cardratings.com/credit-card/wells-fargo-business-elite-card
# https://www.cardratings.com/credit-card/wells-fargo-business-platinum-credit-card
# https://www.cardratings.com/credit-card/wells-fargo-business-secured-credit-card--review
# https://www.cardratings.com/credit-card/wells-fargo-cash-back-sm-college-card
# https://www.cardratings.com/credit-card/wells-fargo-visa-signature-card.html
# https://www.cardratings.com/credit-card/westjet-rbc-mastercard.html
# https://www.cardratings.com/credit-card/westjet-rbc-world-elite-mastercard.html
# https://www.cardratings.com/credit-card/whitetails-unlimited-visa-rewards-card-review
# https://www.cardratings.com/credit-card/world-wildlife-fund-visa-card.html
# https://www.cardratings.com/credit-card/wyndham-rewards-visa-signature-card
# https://www.cardratings.com/credit-card/wyndham-rewards-visa-signature-no-annual-fee-card
# https://www.cardratings.com/credit-card/zions-bank-amazing-cash-credit-card
# https://www.cardratings.com/credit-card/zions-bank-amazing-cash-for-business.html
# https://www.cardratings.com/credit-card/amazing-rate-for-business.html
# https://www.cardratings.com/credit-card/zions-bank-amazing-rate-low-rate-credit-card
# https://www.cardratings.com/credit-card/zions-bank-amazing-rewards-credit-card
# https://www.cardratings.com/credit-card/amazing-rewards-for-business.html

# %% [markdown]
# # The following functions are what we're gonna move over to our module

# %%
## To find basic info about a credit card

def make_soup(url):
    """ Make a soup object from a url"""
    return BeautifulSoup(requests.get(url).content, 'lxml')

def get_card_name(soup):
    """Find the name of the credit card"""
    tag = soup.find('span', attrs={'itemprop':'name'})
    if not tag:
        return 'Unknown'
    title_list = []
    for t in tag.text.split():
        if '-' in t.lower() or 'review' in t.lower():
            break
        title_list.append(t)
    return ' '.join(title_list)

def get_req_credit(soup):
    """Get the credit required to apply for this card"""
    try:
        tag = soup.find('div', attrs={'class': 'py-1'})
        link = tag.find('a')
        return link.get('data-creditneeded', None)
    except AttributeError:
        return None

def get_application_link(soup):
    try:
        tag = soup.find('div', attrs={'class': 'py-1'})
        link = tag.find('a')
        return link.get('href', None)
    except AttributeError:
        return None

def get_card_type(name):
    """Get the type of credit card it is from it's name"""
    possible_names = ['Visa', 'MasterCard', 'American Express', 'Discover']
    for possible_name in possible_names:
        if possible_name.lower() in name.lower(): 
            return possible_name
    return 'Unknown'



soup = make_soup('https://www.cardratings.com/credit-card/chase-sapphire-reserve.html#covid')
soup = make_soup('https://www.cardratings.com/credit-card/citi-double-cash-card.html')
name = get_card_name(soup)
print(name)
print(get_req_credit(soup))
print(get_application_link(soup))
print(get_card_type(name))
# Out:
# Citi® Double Cash Card
# Excellent
# https://clicks.surehits.com/ListingDisplay/Click/?I=ZGU1NzExZDctNWZhNy00M2NkLWI3ZDYtZWFiNjhhNjk1MDMz&U=aHR0cHM6Ly9jbGljay5saW5rc3luZXJneS5jb20vZnMtYmluL2NsaWNrP2lkPWVsQ3lhRFlLb3p3Jm9mZmVyaWQ9Nzg0MzcyLjE0MzQmdHlwZT0zJnN1YmlkPTAmdTE9JGNsaWNra2V5JA%3d%3d&SI=ZWIzYzliNmItNGQ0MC00NGJmLWJiNzQtMjVjNTExYzAxZTM1&SDT=NjM3MzEwMTY4Njg5OTM3MjY4&T=MQ%3d%3d&BM=MQ%3d%3d&ZZ=1595420069
# Unknown

# %%
## To find point reward information for cards

KEY_WORDS = {
    'flights':['flights', 'airlines','travel', 'air', 'southwest', 'fly'],
    'hotel': ['travel', 'hotel'] ,
    'grocery':['supermarket', 'grocery', 'groceries'],
    'gas':['station', 'gas'],
    #'utilities':['telephone', 'shipping', 'internet', 'cabel'],
    'dining':['restaurants', 'dining'],
    'other':['select', 'rotating']
}

def get_rewards_from_string(string, category, key_words):
    """Get rewards specific for a category with given keywords """
    if not isinstance(string, str):
        return 0.0

    for sentence in string.replace('U.S.', 'US').split('. '):
        if any(map(lambda x: x in sentence.lower(), key_words)):
            try:
                multiplyer = float(re.search('(\d+(?:\.\d+)?)', sentence).group())
                if multiplyer > 15:
                    continue
                return multiplyer
            except AttributeError:
                continue

    return 0.0


def get_info_dict(soup):
    """Reads in the new table format and converts it to a dictionary"""
    
    tables = soup.find_all('div', attrs={'id':'top_features_box'})
    table_info = {}
    for table in tables:
        for entry in table.find_all('div', attrs={'class':'col-12 px-5 mt-4'}):
            table_info[entry.find('div', attrs={'class':'gridTitle'}).text.lstrip('\n\xa0')] = \
                entry.find('div', attrs={'class':'mt-1'}).text
    return table_info

def get_annual_bonus(table_info):
    bonus_text = table_info.get('Bonus Rewards', '')
    bonuses = re.compile('\$(\d+)').findall(bonus_text)
    return_value = 0
    for bonus in bonuses:
        return_value += float(bonus)
    return return_value


TYPE1_KEYS = sorted(['Rewards', 'Bonus Rewards', 'Annual Fee'])
TYPE2_KEYS = sorted(['Cash Back on Gas', 'Cash Back on Groceries', 'Cash Back on Other'])
def get_reward_points_from_dict(table_info):
    
    rewards = {}
    flat_cash_back = False
    rewards['flat_cash_back'] = flat_cash_back
    for key in KEY_WORDS.keys():
        rewards[key] = 0.0
    
    if TYPE1_KEYS == sorted(list(table_info.keys())):
        string = table_info['Rewards']
        for category, key_words in KEY_WORDS.items():
            rewards[category] = get_rewards_from_string(string, category, key_words)

    elif TYPE2_KEYS == sorted(list(table_info.keys())):
        for category, key in zip(['gas', 'grocery', 'other'], TYPE2_KEYS):
            try:
                info = table_info[key]
                if "1% when you buy plus 1% as you pay" in info:
                    point_value = 2.0
                    flat_cash_back = True
                else:
                    regexes = [re.compile('\d[.-]\d'), re.compile('\d')]
                    for regex in regexes:
                        match = regex.findall(info)
                        if match:
                            break
                    if '-' in match[0]:
                        point_value = max([float(i) for i in match[0].split('-')])
                    else:
                        point_value = float(match[0])
            except:
                point_value = 0.0 
            if point_value == 1.5: flat_cash_back = True
            rewards[category] = point_value
    else:
        return rewards
    rewards['flat_cash_back'] = flat_cash_back
    return rewards


def clean_rewards_dict(rewards):
    """
    If there are rewards for some categories, these cards will have at least 
    1 point in all other categories. This fixes that
    """
    default_value = 1.0
    if not (np.array(list(rewards.values())) >= 1).any():
        return rewards
    
    if rewards['flat_cash_back']:
        point_value = np.array(list(rewards.values())).max()
        for key in rewards.keys():
            if key == 'flat_cash_back': continue
            rewards[key] = point_value
        
    for key, value in rewards.items():
        if key == 'flat_cash_back': continue
        if value == 0:
            rewards[key] = default_value
    return rewards

def get_rewards_from_paragraph(soup, key_words):
    """A backup function to find rewards from the block if need be"""
    return None


def get_rewards_from_soup(soup):
    """Combines functions from above fo get all rewards from a soup object """
    table_info = get_info_dict(soup)
    rewards = get_reward_points_from_dict(table_info)
    rewards['annual_bonus'] = get_annual_bonus(table_info)
    if not rewards:
        return get_rewards_from_string(tag.text, category, key_words)
    rewards = clean_rewards_dict(rewards)
    return rewards

def find_rotating(soup, rewards):
    if not (np.array(list(rewards.values())) == 5.0).any():
        return False
    tags = soup.find_all('article')
    for tag in tags:
        if 'rotating' in tag.text.lower():
            return True
    return False

NO_ANNUAL_FEE_TO_REMOVE =[
    'neither has an annual fee',
    'no annual fee',
    'neither card has an annual fee',
    'does not charge an annual fee',
    'technically have an annual fee',
    "doesn't charge an annual fee",
]

def get_annual_fee(soup):
    def monetize(string):
        try:
            return float(re.search('\$\d+', string).group()[1:])
        except AttributeError:
            return 0.
    table_info = get_info_dict(soup)
    if 'Annual Fee' in table_info.keys():
        return monetize(table_info['Annual Fee'])
    
    fee = 0
    found_one  = False
    for tag in soup.find_all('div', attrs={'itemprop':'description'}):
        for sentence in tag.text.split('\n'):
            for annual_fee_to_remove in NO_ANNUAL_FEE_TO_REMOVE:
                sentence = sentence.lower().replace(annual_fee_to_remove, '')
            if found_one: continue
            if 'annual fee ' in sentence:
                print(sentence)
                found_one = True
                fee = monetize(sentence)
    if not found_one:
        return 0
    return fee

soup = make_soup('https://www.cardratings.com/credit-card/chase-sapphire-reserve.html#covid')
rewards = get_rewards_from_soup(soup)
print(rewards)
print(find_rotating(soup, rewards))
print(get_annual_fee(soup))
# Out:
# {'flat_cash_back': False, 'flights': 3.0, 'hotel': 3.0, 'grocery': 1.0, 'gas': 1.0, 'dining': 3.0, 'other': 1.0, 'annual_bonus': 754.0}
# False
# 550.0

# %%
def get_rewards_from_url(url):
    soup = make_soup(url)
    name = get_card_name(soup)
    print(name)
    print(url)
    print()
    req_credit = get_req_credit(soup)
    application_link = get_application_link(soup)
    card_type = get_card_type(name)
    rewards = get_rewards_from_soup(soup)
    rewards['rotating'] = find_rotating(soup, rewards)
    
    rewards['name'] = name
    rewards['req_credit'] = req_credit
    rewards['application_link'] = application_link
    rewards['card_type'] = card_type
    rewards['annual_fee'] = get_annual_fee(soup)
    if rewards['annual_fee'] < rewards['annual_bonus']:
        rewards['annual_bonus'] = 0 #probably a one time bonus, not an annual bonus
    rewards['review_link'] = url
    return rewards
    
get_rewards_from_url('https://www.cardratings.com/credit-card/discover-it-cash-back.html')
# Out:
# Discover it® Cash Back
# https://www.cardratings.com/credit-card/discover-it-cash-back.html
# {'flat_cash_back': False,
#  'flights': 1.0,
#  'hotel': 1.0,
#  'grocery': 5.0,
#  'gas': 5.0,
#  'dining': 1.0,
#  'other': 5.0,
#  'annual_bonus': 0,
#  'rotating': True,
#  'name': 'Discover it® Cash Back',
#  'req_credit': None,
#  'application_link': None,
#  'card_type': 'Discover',
#  'annual_fee': 0,
#  'review_link': 'https://www.cardratings.com/credit-card/discover-it-cash-back.html'}

# %%
database = []
for url in cc_urls:
    database.append(get_rewards_from_url(url))
# Out:
# ABOC Platinum Rewards Mastercard® Credit Card
# https://www.cardratings.com/credit-card/aboc-platinum-rewards-credit-card.html
#
# there is also a $35 annual fee for opensky®; the aboc platinum rewards mastercard® credit card  doesn't have an annual fee.
# Aer Lingus Visa Signature® Card
# https://www.cardratings.com/credit-card/aer-lingus-visa-signature-card.html
#
# American Airlines AAdvantage MileUp℠ Card
# https://www.cardratings.com/credit-card/american-airlines-aadvantage-mileup-card.html
#
# AAA® Member Rewards Visa Signature® Card
# https://www.cardratings.com/credit-card/aaa-member-rewards-visa-signature-card.html
#
# AACS
# https://www.cardratings.com/credit-card/aacs-american-association-of-christian-schools-visa-credit-card-review
#
# AARP® Credit Card from Chase
# https://www.cardratings.com/credit-card/aarp-visa-signature-card.html
#
# AEO, Inc. Credit Card
# https://www.cardratings.com/credit-card/aeo-inc.-credit-card.html
#
# AEO, Inc. Visa® Card
# https://www.cardratings.com/credit-card/aeo-inc-visa-card
#
# Abercrombie & Fitch Credit Card
# https://www.cardratings.com/credit-card/abercrombie-fitch-credit-card
#
# Agriculture Federal Credit Union Secured Visa® Classic
# https://www.cardratings.com/credit-card/afcu-agriculture-federal-credit-union-secured-visa-classic
#
# Agriculture Federal Credit Union Visa® Classic
# https://www.cardratings.com/credit-card/afcu-agriculture-federal-credit-union-visa-classic
#
# Agriculture Federal Credit Union Visa® Platinum (no Rebate)
# https://www.cardratings.com/credit-card/afcu-agriculture-federal-credit-union-visa-platinum-no-rebates.html
#
# Agriculture Federal Credit Union Visa® Platinum (with Rebates)
# https://www.cardratings.com/credit-card/afcu-agriculture-federal-credit-union-visa-platinum
#
# Air Force Federal Credit Union Visa® Platinum Card
# https://www.cardratings.com/credit-card/air-force-federal-credit-union-platinum-visa
#
# Allegiant World Mastercard®
# https://www.cardratings.com/credit-card/allegiant-world-mastercard-review
#
# AmTrust Bank 2% Cash Back Visa® Card
# https://www.cardratings.com/credit-card/amtrust-bank-american-express-silver-card.html
#
# AmTrust Bank Platinum Edition® Visa® Card
# https://www.cardratings.com/credit-card/amtrust-bank-platinum-edition-visa-card.html
#
# Amalgamated Bank MasterCard Gold Plus
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-personal-gold-plus
#
# Amalgamated Bank MasterCard Gold Secured
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-gold-secured
#
# Amalgamated Bank MasterCard Standard Plus
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-personal-standard-plus
#
# Amalgamated Bank MasterCard Standard Secured
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-standard-secured
#
# Amalgamated Bank MasterCard Union Card
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-union
#
# Amalgamated Bank MasterCard Union Plus
# https://www.cardratings.com/credit-card/amalgamated-bank-mastercard-union-plus
#
# Amazon Prime Rewards Visa Signature Card
# https://www.cardratings.com/credit-card/amazon-prime-rewards-visa-signature-card-review
#
# neither card charges an annual fee and both offer 5 percent back on a category of purchases. while the amazon prime rewards visa signature card lets you maximize points on amazon and whole foods purchases, discover it® cash back offers 5 percent cash back on up to $1,500 spent in categories that rotate each quarter (you must activate the bonus categories quarterly in order to earn at that rate).
# Amazon Rewards Visa® Signature Card
# https://www.cardratings.com/credit-card/amazon-rewards-visa-signature-card
#
# America's First FCU VISA® Indie
# https://www.cardratings.com/credit-card/americas-first-fcu-indie-visa.html
#
# America's First FCU Visa® Platinum
# https://www.cardratings.com/credit-card/americas-first-fcu-platinum-visa.html
#
# America's First FCU Visa® Platinum Plus
# https://www.cardratings.com/credit-card/americas-first-fcu-visa-platinum-plus.html
#
# America's First FCU Visa® Platinum Pro
# https://www.cardratings.com/credit-card/americas-first-fcu-visa-platinum-pro
#
# America's First FCU Visa® Secured
# https://www.cardratings.com/credit-card/americas-first-fcu-visa-secured.html
#
# American Airlines AAdvantage® Aviator® Business Mastercard®
# https://www.cardratings.com/credit-card/american-airlines-aadvantage-aviator-business-mastercard-review
#
# American Airlines AAdvantage® Aviator® Red World Elite Mastercard®
# https://www.cardratings.com/credit-card/american-airlines-aadvantage-aviator-red-world-elite-mastercard-review
#
# Unknown
# https://www.cardratings.com/credit-card/american-savings-bank-2%-unlimited-cash-back-business-rewards-visa-card.html
#
# Unknown
# https://www.cardratings.com/credit-card/american-savings-bank-2%-unlimited-cash-back-visa-card-review
#
# American Savings Bank Business Edition® Secured Visa® Card
# https://www.cardratings.com/credit-card/american-savings-bank-business-edition-secured-visa-card-review
#
# American Savings Bank Business Edition® Visa® Card
# https://www.cardratings.com/credit-card/american-savings-bank-business-edition-visa-card.html
#
# American Savings Bank Business Edition® Visa® Card with Reward Simplicity
# https://www.cardratings.com/credit-card/amrican-savings-bank-business-edition-visa-card-with-reward-simplicity-review
#
# American Savings Bank Maximum Rewards® Visa® Card
# https://www.cardratings.com/credit-card/american-savings-bank-complete-rewards-visa-card.html
#
# American Savings Bank Platinum Edition® Visa® Card
# https://www.cardratings.com/credit-card/american-savings-bank-platinum-edition-visa-card.html
#
# American Savings Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/american-savings-bank-secured-visa-card.html
#
# Amtrak Guest Rewards® World MasterCard® Credit Card
# https://www.cardratings.com/credit-card/amtrak-guest-rewards-world-mastercard-credit-card-review
#
# Amtrust Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/amtrust-bank-secured-visa-card-review
#
# Animal Friends Visa® Card
# https://www.cardratings.com/credit-card/the-animal-friends-visa-platinum-rewards-card
#
# Ann Taylor Card
# https://www.cardratings.com/credit-card/ann-taylor-credit-card
#
# Ann Taylor MasterCard
# https://www.cardratings.com/credit-card/ann-taylor-mastercard
#
# Anvil Brand Visa® Credit Card
# https://www.cardratings.com/credit-card/anvil-brand-visa-credit-card-review
#
# Applied Bank® Secured Visa® Gold Preferred® Credit Card
# https://www.cardratings.com/credit-card/applied-bank-secured-visa-credit-card.html
#
# Arbor Day Foundation Rewards Visa® Card
# https://www.cardratings.com/credit-card/arbor-day-foundation-rewards-visa-card-review
#
# Arizona Cardinals NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/arizona-cardinals-nfl-extra-points-from-barclays-bank-delaware
#
# Arizona Diamondbacks® BankAmericard Cash Rewards™ MasterCard®
# https://www.cardratings.com/credit-card/arizona-diamondbacks-bankamericard-cash-rewards-mastercard
#
# Armed Forces Bank Credit Builder Secured Visa® Credit Card
# https://www.cardratings.com/credit-card/armed-forced-bank-credit-builder-secured-visa-credit-card.html
#
# Armed Forces Bank Visa® Credit Card
# https://www.cardratings.com/credit-card/armed-forces-bank-visa-gold-credit-card
#
# Arvest Corporate Visa® Card
# https://www.cardratings.com/credit-card/arvest-corporate-visa-card
#
# Arvest Elite Purchasing Visa® Card
# https://www.cardratings.com/credit-card/arvest-elite-purchasing-visa-card
#
# Arvest Visa® Classic
# https://www.cardratings.com/credit-card/arvest-visa-card
#
# Arvest Visa® Gold Card
# https://www.cardratings.com/credit-card/arvest-visa-gold-card
#
# Arvest Visa® Platinum Card
# https://www.cardratings.com/credit-card/arvest-visa-platinum-card
#
# Ashley Stewart Credit Card
# https://www.cardratings.com/credit-card/ashley-stewart-credit-card
#
# Associated Bank American Express® Cash Rewards Card
# https://www.cardratings.com/credit-card/associated-bank-american-express-cash-rewards-credit-card-review
#
# Associated Bank American Express® Premier Rewards Card
# https://www.cardratings.com/credit-card/associated-bank-american-express-premier-rewards-card-review
#
# Associated Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/associated-bank-visa-business-cash-card-review
# Associated Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/associated-bank-visa-platinum-business-real-rewards-card
#
# Associated Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/associated-bank-visa-business-rewards-plus-card
#
# Associated Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/associated-bank-visa-platinum-card
#
# Associated Bank Visa® Secured Card
# https://www.cardratings.com/credit-card/associated-bank-visa-secured-card
#
# Associated Bank Visa® Signature Real Rewards Card
# https://www.cardratings.com/credit-card/associated-bank-visa-signature-card
#
# Atlanta Braves® BankAmericard Cash Rewards™ MasterCard®
# https://www.cardratings.com/credit-card/atlanta-braves-bankamericard-cash-rewards-mastercard
#
# Atlanta Falcons NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/atlanta-falcons-nfl-extra-points-visa-card-from-barclays-bank-delaware
#
# British Airways Visa Signature® Card
# https://www.cardratings.com/credit-card/british-airways-visa-signature-card.html
#
# as an added bonus, every calendar year that you spend at least $30,000 on your card you'll earn a travel together ticket for a companion, good for two years. simply redeem your avios for a british airways reward flight and use your voucher to take someone special with you in the same cabin. the seat is complimentary! all you pay are the taxes and airlines fees. that companion ticket alone more than offsets the $95 annual fee for this card.
# BAMSL Visa Signature® Rewards Card
# https://www.cardratings.com/credit-card/bamsl-visa-signature-rewards-card-review
#
# BB&T Bright Card
# https://www.cardratings.com/credit-card/bbt-bright-card.html
#
# BB&T Bright Low APR Secured Credit Card
# https://www.cardratings.com/credit-card/bbt-bright-secured-credit-card-review
#
# BB&T Bright for Business Credit Card
# https://www.cardratings.com/credit-card/bbt-bright-for-business-credit-card-review
#
# BB&T Cash Rewards Secured Credit Card
# https://www.cardratings.com/credit-card/bbt-cash-rewards-secured-credit-card-review
#
# BB&T Spectrum Cash Rewards Card
# https://www.cardratings.com/credit-card/bbt-spectrum-rewards-card.html
#
# BB&T Spectrum Cash Rewards for Business Credit Card
# https://www.cardratings.com/credit-card/bbt-spectrum-cash-rewards-for-business-credit-card-review
#
# BB&T Spectrum Travel Rewards Credit Card
# https://www.cardratings.com/credit-card/bbt-spectrum-travel-rewards-credit-card-review
#
# BB&T Spectrum Travel Rewards for Business Credit Card
# https://www.cardratings.com/credit-card/bbt-spectrum-travel-rewards-for-business-credit-card-review
#
# BB&T Travel Rewards Secured Credit Card
# https://www.cardratings.com/credit-card/bbttravel-rewards-secured-credit-card-review
#
# BB&T Vantage® Visa Signature® Credit Card
# https://www.cardratings.com/credit-card/bbt-vantage-visa-signature-credit-card-review
#
# BBVA ClearPoints Credit Card
# https://www.cardratings.com/credit-card/bbva-clearpoints-credit-card-review
#
# BBVA Optimizer Credit Card®
# https://www.cardratings.com/credit-card/bbva-optimizer-credit-card-review
#
# BBVA Rewards Card
# https://www.cardratings.com/credit-card/bbva-rewards-card-review
#
# BBVA Secured Visa® Business Credit Card
# https://www.cardratings.com/credit-card/bbva-secured-visa-business-credit-card-review
#
# BBVA Select℠ Credit Card
# https://www.cardratings.com/credit-card/bbva-select-credit-card-review
#
# BBVA Visa® Business Rewards Credit Card
# https://www.cardratings.com/credit-card/bbva-visa-business-rewards-credit-card-review
#
# BMO Harris Bank Business Platinum Mastercard® Credit Card
# https://www.cardratings.com/credit-card/bmo-harris-bank-business-platinum-mastercard-credit-card-review
#
# BMO Harris Bank Business Platinum Rewards Mastercard® Credit Card
# https://www.cardratings.com/credit-card/bmo-harris-bank-business-platinum-rewards-mastercard-credit-card-review
#
# BMO Harris Bank Cash Back Mastercard®
# https://www.cardratings.com/credit-card/bmo-harris-bank-cash-back-mastercard-review
#
# BMO Harris Bank Platinum Rewards Mastercard®
# https://www.cardratings.com/credit-card/bmo-harris-bank-platinum-rewards-mastercard-review
#
# BMO Harris Bank Premium Rewards Mastercard®
# https://www.cardratings.com/credit-card/bmo-harris-bank-premium-rewards-mastercard-review
#
# BMW Card
# https://www.cardratings.com/credit-card/bmw-card-review
#
# BMW Precisioin Card
# https://www.cardratings.com/credit-card/bmw-precision-card-review
#
# BTC Bank Visa® Credit Card
# https://www.cardratings.com/credit-card/btc-bank-visa-credit-card-review
#
# Ballston Spa National Bank Cash Rewards Platinum Card
# https://www.cardratings.com/credit-card/ballston-spa-national-bank-cash-rewards-platinum-card-review
#
# Ballston Spa National Bank Visa® Platinum Rewards Credit Card
# https://www.cardratings.com/credit-card/ballston-spa-natl-bank-visa-platinum-credit-card.html
#
# Ballston Spa National Bank Visa® Small Business Cash Rewards Card
# https://www.cardratings.com/credit-card/ballston-spa-national-bank-visa-small-business-cash-rewards-card--review
#
# Ballston Spa National Bank Visa® Small Business Edition Card
# https://www.cardratings.com/credit-card/ballston-spa-national-bank-visa-small-business-edition-card-review
#
# Ballston Spa National Bank Visa® Small Business Rewards Card
# https://www.cardratings.com/credit-card/ballston-spa-national-bank-visa-small-business-rewards-card-review
#
# Baltimore Orioles® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/baltimore-orioles-bankamericard-cash-rewards-mastercard
#
# Baltimore Ravens NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/baltimore-ravens-nfl-extra-points-from-barclays-bank-delaware
#
# Banana Republic Credit Card
# https://www.cardratings.com/credit-card/banana-republic-credit-card
#
# Banana Republic Visa® Card
# https://www.cardratings.com/credit-card/banana-republic-visa-card
#
# Bangor Savings Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-cash-rewards-american-express-card-review
#
# Bangor Savings Bank College Rewards Visa® Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-college-rewards-visa-card
#
# Bangor Savings Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-premier-rewards-american-express-card-review
#
# Bangor Savings Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-secured-visa-card.html
#
# Bangor Savings Bank Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-signature-card
#
# Bangor Savings Bank Visa® Business Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-business-card
#
# Bangor Savings Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-business-cash-card-review
#
# Bangor Savings Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-business-travel-card
#
# Bangor Savings Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-platinum-business-rewards-card
#
# Bangor Savings Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/bangor-savings-bank-visa-platinum-card
#
# Bank of America® Cash Rewards for Students
# https://www.cardratings.com/credit-card/bank-of-america-cash-rewards-for-students.html
#
# Bank of America® Travel Rewards Credit Card for Students
# https://www.cardratings.com/credit-card/bank-of-america-travel-rewards-credit-card-for-students
#
# Bank of Oklahoma Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/bank-of-oklahoma-cash-rewards-american-express-card-review
#
# Bank of Oklahoma Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/bank-of-oklahoma-premier-rewards-american-express-card-review
#
# Bank of Oklahoma Secured Visa®
# https://www.cardratings.com/credit-card/bank-of-oklahoma-secured-visa-review
#
# Bank of Oklahoma Visa Real Rewards
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-real-rewards-review
#
# Bank of Oklahoma Visa® Business Card
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-business-card-review
#
# Bank of Oklahoma Visa® Business Cash Card
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-business-cash-card-review
# Bank of Oklahoma Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-business-real-rewards-card-review
#
# Bank of Oklahoma Visa® Business Rewards Plus Card
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-business-rewards-plus-card-review
#
# Bank of Oklahoma Visa® College Real Rewards
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-college-real-rewards-review
#
# Bank of Oklahoma Visa® Platinum Card
# https://www.cardratings.com/credit-card/bank-of-oklahoma-visa-platinum-card-review
#
# Bank of the West Business Mastercard®
# https://www.cardratings.com/credit-card/bank-of-the-west-business-mastercard-review
#
# Bank of the West Business Rewards Mastercard®
# https://www.cardratings.com/credit-card/bank-of-the-west-business-rewards-mastercard-review
#
# Bank of the West Cash Back World Credit Card
# https://www.cardratings.com/credit-card/bank-of-the-west-cash-back-world-credit-card-review
#
# Bank of the West Platinum Credit Card
# https://www.cardratings.com/credit-card/bank-of-the-west-platinum-credit-card-review
#
# Bank of the West Secured Credit Card
# https://www.cardratings.com/credit-card/bank-of-the-west-secured-credit-card-review
#
# BankAmericard® Credit Card for Students
# https://www.cardratings.com/credit-card/bankamericard-credit-card-for-students.html
#
# Barclaycard Financing Visa® Card
# https://www.cardratings.com/credit-card/barclaycard-financing-visa-card.html
#
# Barnes & Noble MasterCard®
# https://www.cardratings.com/credit-card/barnes-noble-mastercard
#
# Bealls Florida Credit Card
# https://www.cardratings.com/credit-card/bealls-florida-credit-card
#
# Belk Rewards Card
# https://www.cardratings.com/credit-card/belk-rewards-card
#
# Berkshire Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/berkshire-bank-cash-rewards-american-express-card.html
#
# Berkshire Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/berkshire-bank-premier-rewards-american-express-card
#
# Berkshire Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-secured-visa-card
#
# Berkshire Bank Visa Signature® College Real Rewards Card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-college-rewards-visa-card
#
# Berkshire Bank Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-signature-card
#
# Berkshire Bank Visa® Business Card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-business-card
#
# Berkshire Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/berkshire-bank-visa-business-cash-card-review
#
# Berkshire Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-platinum-business-rewards-card
#
# Berkshire Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-business-travel-card
#
# Berkshire Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/berkshire-municipal-bank-visa-platinum-card
#
# Bethpage FCU MasterCard® Be You Rewards Credit Card
# https://www.cardratings.com/credit-card/bethpage-fcu-mastercard-platinum-rewards-credit-card.html
#
# Bethpage FCU MasterCard® Cash Back Credit Card
# https://www.cardratings.com/credit-card/bethpage-fcu-mastercard-cash-back-credit-card.html
#
# Bethpage FCU MasterCard® Low Rate Credit Card
# https://www.cardratings.com/credit-card/bethpage-fcu-mastercard-low-rate-credit-card.html
#
# Bloomingdale's American Express® Card
# https://www.cardratings.com/credit-card/bloomingdales-american-express-card-review
#
# Bloomingdale's Credit Card
# https://www.cardratings.com/credit-card/bloomingdales-credit-card
#
# Boston Red Sox® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/boston-red-sox-bankamericard-cash-rewards-mastercard
#
# Bremer Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/bremer-bank-cash-rewards-american-express-card-review
#
# Bremer Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/bremer-bank-premier-rewards-american-express-card-review
#
# Bremer Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/bremer-bank-visa-business-cash-card-review
#
# Bremer Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/bremer-bank-visa-business-real-rewards-card-review
#
# Bremer Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/bremer-bank-visa-business-rewards-plus-card-review
#
# Bremer Bank Visa® College Rewards Card
# https://www.cardratings.com/credit-card/bremer-bank-visa-college-rewards-card-review
#
# Bremer Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/bremer-bank-visa-platinum-card-review
#
# Bremer Bank Visa® Real Rewards Card
# https://www.cardratings.com/credit-card/bremer-bank-visa-real-rewards-card-review
#
# Bremer Bank Visa® Secured Card
# https://www.cardratings.com/credit-card/bremer-bank-visa-secured-card-review
#
# Bryant University Alumni Visa® Rewards Card
# https://www.cardratings.com/credit-card/bryant-university-alumni-visa-rewards-card-review
#
# BrylaneHome Credit Card
# https://www.cardratings.com/credit-card/brylanehome-credit-card
#
# Buffalo Bills NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/buffalo-bills-nfl-extra-points-from-barclays-bank-delaware
#
# CareCredit® credit card
# https://www.cardratings.com/credit-card/synchrony-care-credit-card.html
#
# Chase Freedom Unlimited®
# https://www.cardratings.com/credit-card/chase-freedom-unlimited.html
#
# chase freedom unlimited® includes a lot of the features you’ve come to appreciate in the chase freedom® (this card is not currently available on cardratings) card, like a $0 annual fee and a sweet offer of 0% intro apr on purchases for 15 months, then 14.99 - 23.74% variable after that, but it also carries with it a few notable (and enticing) differences: namely, no rotating categories, no quarterly enrollments, and no cap on what you can earn. on an ongoing basis, the chase freedom unlimited® card offers users the chance to earn unlimited 1.5% cash back on every purchase – it's automatic. no hoops, no hassles, no questions asked.
# Chase Sapphire Reserve®
# https://www.cardratings.com/credit-card/chase-sapphire-reserve.html
#
# Citi Rewards+℠ Card
# https://www.cardratings.com/credit-card/citi-rewards-plus-card.html
#
# Citi® / AAdvantage® Executive World Elite™ Mastercard®
# https://www.cardratings.com/credit-card/citi-aadvantage-executive-world-elite-mastercard.html
#
# plus, when you become a card member, you receive a complimentary admirals club® membership which gains you, and up to two guests or your immediate family members, access to dozens of airport lounges worldwide. with household membership prices averaging anywhere from $625 to $925 a year, this membership is a great incentive for those looking for a more comfortable way to travel and easily offsets the $450 annual fee you'll pay to carry the citi® / aadvantage® executive world elite™ mastercard®.
# Citi® / AAdvantage® Platinum Select® World Elite™ Mastercard®
# https://www.cardratings.com/credit-card/citi-aadvantage-platinum-select-mastercard.html
#
# Citi® Diamond Preferred®
# https://www.cardratings.com/credit-card/citi-diamond-preferred-card
#
# Citi® Double Cash Card
# https://www.cardratings.com/credit-card/citi-double-cash-card.html
#
# CitiBusiness® / AAdvantage® Platinum Select® Mastercard®
# https://www.cardratings.com/credit-card/citibusiness-aadvantage-platinum-select-mastercard.html
#
# Costco Anywhere Visa® Card by Citi
# https://www.cardratings.com/credit-card/costco-anywhere-visa-card-by-citi.html
#
# Credit One Bank® Visa® Credit Card
# https://www.cardratings.com/credit-card/credit-one-bank-visa-credit-card.html
#
# CCSU Alumni Rewards Visa® Card
# https://www.cardratings.com/credit-card/ccsu-alumni-rewards-visa-card-review
#
# CFCU Business Visa
# https://www.cardratings.com/credit-card/cfcu-visa-classic.html
#
# CFCU Classic Visa
# https://www.cardratings.com/credit-card/cfcu-credit-union-classic-visa
#
# CFCU Platinum Visa
# https://www.cardratings.com/credit-card/cfcu-credit-union-platunum-visa
#
# CFCU Rewards Visa
# https://www.cardratings.com/credit-card/cfcu-rewards-visa-card.html
# CFCU Secured Classic Plus Visa
# https://www.cardratings.com/credit-card/cfcu-credit-union-secured-classic-plus-visa
#
# Cabela's Club Mastercard
# https://www.cardratings.com/credit-card/cabelas-club-mastercard-review
#
# CarCareONE® Credit Card
# https://www.cardratings.com/credit-card/carcareone-credit-card--review
#
# CareCredit® Credit Card
# https://www.cardratings.com/credit-card/carecredit-credit-card-review
#
# Carnival® FunPoints World MasterCard®
# https://www.cardratings.com/credit-card/carnival-funpoints-world-mastercard
#
# Carolina Panthers NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/carolina-panthers-nfl-extra-points-from-barclays-bank-delaware
#
# Catherines Credit Card
# https://www.cardratings.com/credit-card/catherines-credit-card
#
# Celebrity Cruises® Visa Signature® Credit Card
# https://www.cardratings.com/credit-card/celebrity-cruises-visa-signature-credit-card.html
#
# Chemical Bank Maximum Rewards® Card
# https://www.cardratings.com/credit-card/chemical-bank-maximum-rewards-card-review
#
# Chemical Bank Platinum Edition® Card
# https://www.cardratings.com/credit-card/chemical-bank-platinum-edition-card-review
#
# Chemical Bank Secured Visa
# https://www.cardratings.com/credit-card/chemical-bank-secured-visa-review
#
# Chevron and Texaco Techron Advantage™ Card
# https://www.cardratings.com/credit-card/chevron-and-texaco-credit-card-review
#
# Chevron and Texaco Techron Advantage™ Visa® Card
# https://www.cardratings.com/credit-card/chevron-and-texaco-visa-card-review
#
# Chicago Bears NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/chicago-bears-nfl-extra-points-from-barclays-bank-delaware
#
# Chicago Cubs® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/chicago-cubs-bankamericard-cash-rewards-mastercard
#
# Chicago White Sox® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/chicago-white-sox-bankamericard-cash-rewards-mastercard
#
# Choice Privileges® Visa Signature® Card
# https://www.cardratings.com/credit-card/choice-privileges-no-annual-fee-visa-signature-card-from-barclays-bank-delaware
#
# Christopher & Banks Credit Card
# https://www.cardratings.com/credit-card/christopher-banks-credit-card-review
#
# Cincinnati Bengals NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/cincinnati-bengals-nfl-extra-points-from-barclays-bank-delaware
#
# Cincinnati Reds® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/cincinnati-reds-bankamericard-cash-rewards-mastercard
#
# Citizens Bank Business Platinum Mastercard®
# https://www.cardratings.com/credit-card/citizens-bank-business-platinum-mastercard-review
#
# Citizens Bank Cash Back Plus® World Mastercard®
# https://www.cardratings.com/credit-card/citizens-bank-cash-back-plus-world-mastercard-review
#
# Citizens Bank Clear Value® Mastercard®
# https://www.cardratings.com/credit-card/citizens-bank-clear-value-mastercard-review
#
# City National Bank Crystal® Visa Infinite® Card with City National Rewards
# https://www.cardratings.com/credit-card/city-national-crystal-visa-rewards-card.html
#
# City National Bank Visa Cash Back Signature Card
# https://www.cardratings.com/credit-card/city-national-bank-visa-cash-back-signature-card-review
#
# City National Bank Visa Platinum Card with City National Rewards
# https://www.cardratings.com/credit-card/city-national-bank-visa-platinum-credit-card-with-city-national-rewards
#
# City National Bank Visa Signature® Card with City National Rewards
# https://www.cardratings.com/credit-card/city-national-bank-visa-signature-credit-card-with-city-national-rewards
#
# Clark Crown Endless Rewards MasterCard®
# https://www.cardratings.com/credit-card/clark-crown-endless-rewards-mastercard-review
#
# Cleveland Browns NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/cleveland-browns-nfl-extra-points-from-barclays-bank-delaware
#
# Cleveland Indians® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/cleveland-indians-bankamericard-cash-rewards-mastercard
#
# Colorado Rockies® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/colorado-rockies-bankamericard-cash-rewards-mastercard
#
# Columbia Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/columbia-bank-cash-rewards-american-express-card-review
#
# Columbia Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/columbia-bank-premier-rewards-american-express-card-review
#
# Columbia Bank Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/columbia-bank-visa-signature-real-rewards-card-review
#
# Columbia Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/columbia-bank-visa-business-cash-card-review
#
# Columbia Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/columbia-bank-visa-business-real-rewards-card-review
#
# Columbia Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/columbia-bank-visa-business-rewards-plus-card-review
#
# Columbia Bank Visa® College Real Rewards
# https://www.cardratings.com/credit-card/columbia-bank-visa-college-real-rewards-review
#
# Columbia Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/columbia-bank-visa-platinum-card-review
#
# Columbia Bank Visa® Secured Card
# https://www.cardratings.com/credit-card/columbia-bank-visa-secured-card-review
#
# Commerce Bank Secured Visa® Credit Card
# https://www.cardratings.com/credit-card/commerce-bank-secured-visa-credit-card.html
#
# Commerce Bank Special Connections® MasterCard® with Rewards
# https://www.cardratings.com/credit-card/commerce-bank-special-connectionssm-mastercard-with-rewards.html
#
# Commerce Bank Special Connections® Visa® with Rewards
# https://www.cardratings.com/credit-card/commerce-bank-special-connections-visa-with-rewards
#
# Commerce Bank World Elite MasterCard®
# https://www.cardratings.com/credit-card/commerce-bank-world-elite-mastercard.html
#
# Commerce Bank toggle® Visa® Signature
# https://www.cardratings.com/credit-card/commerce-bank-toggle-visa-signature-review
#
# Crutchfield® Sony Financial Services Card
# https://www.cardratings.com/credit-card/crutchfield-credit-card-review
#
# Deserve Edu
# https://www.cardratings.com/credit-card/deserve-edu.html
#
# DCU Visa® Platinum Credit Card
# https://www.cardratings.com/credit-card/dcu-visa-platinum-credit-card.html
#
# DCU Visa® Platinum Rewards Credit Card
# https://www.cardratings.com/credit-card/dcu-visa-platinum-rewards-credit-card.html
#
# DCU Visa® Platinum Secured Credit Card
# https://www.cardratings.com/credit-card/dcu-visa-platinum-secured-credit-card.html
#
# many secured credit cards charge an annual fee in addition to the security deposst needed to establish your line of credit. the dcu visa® platinum secured credit card is different in that it . the credit limit is still based on the amount of your refundable deposit, which is typical of a secured card.
# Dallas Cowboys NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/dallas-cowboys-nfl-extra-points-from-barclays-bank-delaware
#
# David's Bridal Credit Card
# https://www.cardratings.com/credit-card/davids-bridal-credit-card-review
#
# Denver Broncos NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/denver-broncos-nfl-extra-points-from-barclays-bank-delaware
#
# Detroit Lions NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/detroit-lions-nfl-extra-points-from-barclays-bank-delaware
#
# Detroit Tigers® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/detroit-tigers-major-league-baseball-extra-bases-credit-card
#
# Diamond Resorts World MasterCard®
# https://www.cardratings.com/credit-card/diamond-resorts-international-mastercard.html
#
# Dillons/Baker's/Gerbes REWARDS World Mastercard®
# https://www.cardratings.com/credit-card/dillons-bakers-gerbes-rewards-world-mastercard
#
# Drury Gold Key Club Card
# https://www.cardratings.com/credit-card/drury-gold-club-key-card.html
#
# ESL FCU Visa® Business Card
# https://www.cardratings.com/credit-card/esl-visa-business-card.html
#
# Eastern Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/eastern-bank-cash-rewards-american-express-card-review
# Eastern Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/eastern-bank-premier-rewards-american-express-card-review
#
# Eastern Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/eastern-bank-secured-visa-card-review
#
# Eastern Bank Visa Signature® College Real Rewards Card
# https://www.cardratings.com/credit-card/eastern-bank-visa-signature-college-real-rewards-card-review
#
# Eastern Bank Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/eastern-bank-visa-signature-real-rewards-card-review
#
# Eastern Bank Visa® Business Card
# https://www.cardratings.com/credit-card/eastern-bank-visa-business-card-review
#
# Eastern Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/eastern-bank-visa-business-cash-card-review
#
# Eastern Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/eastern-bank-visa-business-real-rewards-card--review
#
# Eastern Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/eastern-bank-visa-business-rewards-plus-card-review
#
# Eastern Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/eastern-bank-visa-platinum-card-review
#
# Eddie Bauer Credit Card
# https://www.cardratings.com/credit-card/eddie-bauer-credit-card
#
# Evans Bank Visa® Small Business Cash Rewards Card
# https://www.cardratings.com/credit-card/evans-bank-small-business-cash-rewards-card-review
#
# Evans Visa® Cash Rewards Platinum Credit Card
# https://www.cardratings.com/credit-card/evans-visa-cash-rewards-platinum-credit-card-review
#
# Evans Visa® Platinum Edition Credit Card
# https://www.cardratings.com/credit-card/evans-visa-platinum-edition-credit-card-review
#
# Evans Visa® Rewards Platinum Credit Card
# https://www.cardratings.com/credit-card/evans-visa-rewards-platinum-credit-card-review
#
# Evans Visa® Small Business Edition
# https://www.cardratings.com/credit-card/evans-visa-small-business-edition-review
#
# Evans Visa® Small Business Rewards Card
# https://www.cardratings.com/credit-card/evans-visa-small-business-rewards-card-review
#
# Everyday Points® Business Mastercard®
# https://www.cardratings.com/credit-card/everyday-points-business-mastercard-review
#
# Express Next Credit Card
# https://www.cardratings.com/credit-card/express-credit-card
#
# First Access VISA® Solid Black Credit Card
# https://www.cardratings.com/credit-card/first-access-visa-credit-card.html
#
# FLW Fishing League Worldwide Visa® Rewards Card
# https://www.cardratings.com/credit-card/flw-fishing-league-worldwide-visa-rewards-card-review
#
# FNA Florida Nurses Association Visa® Rewards
# https://www.cardratings.com/credit-card/fna-florida-nurses-association-visa-rewards-review
#
# FOP Fraternal Order of Police® Visa® Rewards Credit Card
# https://www.cardratings.com/credit-card/fop-fraternal-order-of-police-visa-rewards-credit-card-review
#
# Family Handyman MasterCard® with Rewards
# https://www.cardratings.com/credit-card/family-handyman-mastercard-with-rewards-review
#
# Fifth Third Secured Card
# https://www.cardratings.com/credit-card/fifth-third-secured-card-review
#
# FifthThird Business Rewards MasterCard
# https://www.cardratings.com/credit-card/fifth-third-business-rewards-mastercard-review
#
# Fingerhut Advantage Credit Account
# https://www.cardratings.com/credit-card/fingerhut-credit-account.html
#
# First Citizens Business Visa® Card
# https://www.cardratings.com/credit-card/first-citizens-business-visa-card-review
#
# First Citizens Rewards Business Visa® Card
# https://www.cardratings.com/credit-card/first-citizens-rewards-business-visa-card-review
#
# First Citizens Rewards Visa® Card
# https://www.cardratings.com/credit-card/first-citizens-rewards-visa-card-review
#
# First Citizens Rewards® Visa® Card Accelerate Your Earnings
# https://www.cardratings.com/credit-card/first-citizens-rewards-visa-card-accelerate-your-earnings-review
#
# First Citizens Rewards® Visa® with Unlimited Cash Back
# https://www.cardratings.com/credit-card/first-citizens-rewards-visa-with-unlimited-cash-back-review
#
# First Citizens Smart Option Visa® Card
# https://www.cardratings.com/credit-card/first-citizens-smart-option-visa-card-review
#
# First Command Bank Classic Visa® Card
# https://www.cardratings.com/credit-card/first-command-bank-classic-visa-card
#
# First Command Bank Platinum Visa® Card
# https://www.cardratings.com/credit-card/first-command-bank-platinum-visa-card
#
# First Hawaiian Bank Business MasterCard®
# https://www.cardratings.com/credit-card/first-hawaiian-bank-business-mastercard.html
#
# First Hawaiian Bank Cash Rewards Business Credit Card
# https://www.cardratings.com/credit-card/first-hawaiian-bank-cash-rewards-business-credit-card.html
#
# First Hawaiian Bank Heritage MasterCard®
# https://www.cardratings.com/credit-card/first-hawaiian-bank-mastercard
#
# First Hawaiian Bank Priority Destinations World Elite MasterCard (Personal and Priority)
# https://www.cardratings.com/credit-card/first-hawaiian-bank-priority-rewards-premier-world-elite-mastercard
#
# First Hawaiian Bank Priority Destinations® World Credit Card
# https://www.cardratings.com/credit-card/first-hawaiian-bank-priority-destinationssm-world-mastercard.html
#
# First Hawaiian Bank Priority Destinations® World Elite Business MasterCard
# https://www.cardratings.com/credit-card/first-hawaiian-bank-priority-destinations-world-elite-business-mastercard.html
#
# First Hawaiian Bank Priority Rewards Business Credit Card℠
# https://www.cardratings.com/credit-card/first-hawaiian-bank-priority-rewards-business-credit-cardsm.html
#
# First Hawaiian Bank United MileagePlus® Business Credit Card
# https://www.cardratings.com/credit-card/united-mileageplus-business-credit-card.html
#
# First Hawaiian Bank United® Credit Card
# https://www.cardratings.com/credit-card/first-hawaiian-bank-united-mileageplus-credit-card
#
# First Horizon Platinum Premier Visa Card
# https://www.cardratings.com/credit-card/first-horizon-platinum-premier-visa-card-review
#
# First Horizon Secured Visa
# https://www.cardratings.com/credit-card/first-horizon-secured-visa-review
#
# First Horizon Visa Signature®
# https://www.cardratings.com/credit-card/first-horizon-visa-signature-review
#
# First Horizon Visa® Classic
# https://www.cardratings.com/credit-card/first-horizon-visa-classic-review
#
# First Internet Bank CASHBACK Credit Card
# https://www.cardratings.com/credit-card/first-internet-bank-of-indiana-cashback-credit-card-review
#
# Unknown
# https://www.cardratings.com/credit-card/connect-classic
#
# First Midwest Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/first-midwest-bank-cash-rewards-american-express-card-review
#
# First Midwest Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/first-midwest-bank-premier-rewards-american-express-card-review
#
# First Midwest Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-business-cash-card-review
#
# First Midwest Bank Visa® Business Platinum Card
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-business-platinum-card-review
#
# First Midwest Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-business-real-rewards-card-review
#
# First Midwest Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-business-rewards-plus-card-review
#
# First Midwest Bank Visa® College Real Rewards Card
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-college-real-rewards-card-review
#
# First Midwest Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-platinum-card-review
#
# First Midwest Bank Visa® Real Rewards Card
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-signature-real-rewards-card-review
#
# First Midwest Bank Visa® Secured Card
# https://www.cardratings.com/credit-card/first-midwest-bank-visa-secured-card-review
#
# First National Bank American Express® Card
# https://www.cardratings.com/credit-card/bucksbacksm-platinum-edition-visa-card
#
# First National Bank Business Edition® Secured Visa® Card
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-business-edition-secured-visa-card-review
#
# First National Bank Business Edition® Visa® Card
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-business-edition-visa-card.html
# First National Bank Complete Rewards® Visa® Card
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-complete-rewards-platinum-edition-visa-card.html
#
# First National Bank Platinum Edition® Visa® Card
# https://www.cardratings.com/credit-card/platinum-edition-visa-card
#
# First National Bank of Omaha Business Edition® Visa® Card with Reward Simplicity
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-business-edition-visa-card-with-reward-simplicity-review
#
# First National Bank of Omaha Secured Visa® Card
# https://www.cardratings.com/credit-card/first-national-bank-of-omaha-secured-visa-card.html
#
# Firstrust Business Platinum Card
# https://www.cardratings.com/credit-card/firstrust-business-platinum-card-review
#
# Firstrust Business Platinum Rewards Card
# https://www.cardratings.com/credit-card/firstrust-business-platinum-rewards-card-review
#
# Firstrust Platinum Rewards Card
# https://www.cardratings.com/credit-card/firstrust-platinum-rewards-card-review
#
# Firstrust Platinum Visa® Card
# https://www.cardratings.com/credit-card/firstrust-platinum-card-review
#
# Five Star Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/five-star-bank-cash-rewards-american-express-card-review
#
# Five Star Bank College Real Rewards Visa® Card
# https://www.cardratings.com/credit-card/five-star-bank-college-rewards-visa-card.html
#
# Five Star Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/five-star-bank-travel-rewards-american-express-card-review
#
# Five Star Bank Secured Visa®
# https://www.cardratings.com/credit-card/five-star-bank-secured-visa
#
# Five Star Bank Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/five-star-bank-visa-signature-bonus-rewards-card
#
# Five Star Bank Visa® Business Card
# https://www.cardratings.com/credit-card/five-star-bank-visa-business-card
#
# Five Star Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/five-star-bank-visa-business-cash-card-review
#
# Five Star Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/five-star-bank-visa-business-bonus-rewards-card
#
# Five Star Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/five-star-bank-visa-business-bonus-rewards-plus-card-review
#
# Five Star Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/five-star-bank-visa-platinum-card
#
# Flagstar Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/flagstar-bank-cash-rewards-american-express-card-review
#
# Flagstar Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/flagstar-bank-premier-rewards-american-express-card-review
#
# Flagstar Bank Visa Real Rewards Card
# https://www.cardratings.com/credit-card/flagstar-bank-visa-real-rewards-card-review
#
# Flagstar Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/flagstar-bank-visa-business-cash-card-review
#
# Flagstar Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/flagstar-bank-visa-business-real-rewards-card-review
#
# Flagstar Bank Visa® Business Rewards Plus Card
# https://www.cardratings.com/credit-card/flagstar-bank-visa-business-rewards-plus-card-review
#
# Flagstar Bank Visa® College Real Rewards Card
# https://www.cardratings.com/credit-card/flagstar-bank-visa-college-real-rewards-card-review
#
# Flagstar Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/flagstar-bank-visa-platinum-card-review
#
# Flagstar Bank Visa® Secured Card
# https://www.cardratings.com/credit-card/flagstar-bank-visa-secured-card-review
#
# Fred Meyer Rewards® World Mastercard®
# https://www.cardratings.com/credit-card/fred-meyer-rewards-visa-card
#
# Frontier Airlines World MasterCard®
# https://www.cardratings.com/credit-card/frontier-airlines-world-mastercard
#
# Fry's Rewards World Mastercard®
# https://www.cardratings.com/credit-card/frys-food-drug-stores-frys-marketplace-123-rewards-visa
#
# Fulton Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/fulton-bank-cash-rewards-american-express-card-review
#
# Fulton Bank College Real Rewards Visa® Card
# https://www.cardratings.com/credit-card/fulton-bank-college-rewards-visa-card.html
#
# Fulton Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/fulton-bank-travel-rewards-american-express-card-review
#
# Fulton Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/fulton-bank-secured-visa-card.html
#
# Fulton Bank Visa® Business Card
# https://www.cardratings.com/credit-card/fulton-bank-visa-business-card.html
#
# Fulton Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/fulton-bank-visa-business-cash-card-review
#
# Fulton Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/fulton-bank-visa-business-bonus-rewards-card.html
#
# Fulton Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/fulton-bank-visa-business-bonus-rewards-plus-card.html
#
# Fulton Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/fulton-bank-visa-platinum-card.html
#
# Fulton Bank Visa® Real Rewards Card
# https://www.cardratings.com/credit-card/fulton-bank-visa-signature-bonus-rewards-plus-card.html
#
# Garden State Community Bank 2% Cash Back Visa® Card
# https://www.cardratings.com/credit-card/garden-state-community-bank-graphitesm-american-express-card.html
#
# Garden State Community Bank Platinum Edition® Visa® Card
# https://www.cardratings.com/credit-card/garden-state-community-bank-platinum-edition-visa-card.html
#
# Garden State Community Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/garden-state-community-bank-secured-visa-card-review
#
# Goody's Credit Card
# https://www.cardratings.com/credit-card/goody-s-credit-card
#
# Gordmans Credit Card
# https://www.cardratings.com/credit-card/gordmans-credit-card
#
# Green Bay Packers NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/green-bay-packers-nfl-extra-points-from-barclays-bank-delaware
#
# Grossman's® Bargain Outlet Credit Card
# https://www.cardratings.com/credit-card/grossmans-bargain-outlet-credit-card-review
#
# Guide Dogs for the Blind Visa® Platinum Rewards Card
# https://www.cardratings.com/credit-card/the-guide-dogs-for-the-blind-visa-platinum-rewards-card
#
# Hilton Honors American Express Aspire Card
# https://www.cardratings.com/credit-card/hilton-honors-card-american-express-aspire-card.html
#
# Hilton Honors American Express Card
# https://www.cardratings.com/credit-card/hilton-honors-card-american-express.html
#
# there is a hefty annual fee of $250, so this card is really designed with a regular traveler in mind.
# Hilton Honors American Express Surpass® Card
# https://www.cardratings.com/credit-card/hilton-honors-surpass-card.html
#
# ...
# https://www.cardratings.com/credit-card/td-cash-visa-credit-card
#
# The Hilton Honors American Express Business Card
# https://www.cardratings.com/credit-card/hilton-honors-business-card-from-american-express-open.html
# The World Of Hyatt Credit Card
# https://www.cardratings.com/credit-card/the-world-of-hyatt-credit-card-from-chase.html
#
# Total VISA® Unsecured Credit Card
# https://www.cardratings.com/credit-card/total-visa-unsecured-credit-card.html
#
# TCF Bank Business Edition® Secured Visa® Card
# https://www.cardratings.com/credit-card/tcf-bank-business-edition-secured-visa-card-review
#
# TCF Bank Business Edition® Visa® Card
# https://www.cardratings.com/credit-card/tcf-bank-business-edition-visa-card-review
#
# TCF Bank Business Edition® Visa® Card with Reward Simplicity
# https://www.cardratings.com/credit-card/tcf-bank-business-edition-visa-card-with-reward-simplicity-review
#
# TCF Bank Maximum Rewards® Visa® Card
# https://www.cardratings.com/credit-card/tcf-bank-maximum-rewards-visa-card-review
#
# TCF Bank Platinum Edition® Visa® Card
# https://www.cardratings.com/credit-card/tcf-bank-platinum-edition-visa-card-review
#
# TCF Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/tcf-bank-secured-visa-card-review
#
# TD Ameritrade® Client Rewards Credit Card
# https://www.cardratings.com/credit-card/td-ameritrade-client-rewards-credit-card-review
#
# TD Business Solutions Visa® Credit Card
# https://www.cardratings.com/credit-card/td-business-solutions-visa-credit-card.html
#
# TD First Class℠ Visa Signature® Credit Card
# https://www.cardratings.com/credit-card/td-first-class-sm-visa-signature-credit-card.html
#
# TJ Maxx® TJX Rewards® Credit Card
# https://www.cardratings.com/credit-card/tj-maxx-credit-card-review
#
# TJX Rewards® Credit Card
# https://www.cardratings.com/credit-card/tjx-rewards-credit-card
#
# TJX Rewards® Platinum MasterCard®
# https://www.cardratings.com/credit-card/tjx-rewards-platinum-mastercard.html
#
# TNA Tennessee Nurses Association Visa® Rewards
# https://www.cardratings.com/credit-card/tna-tennessee-nurses-association-visa-rewards-review
#
# TRIO® Preferred Credit Card
# https://www.cardratings.com/credit-card/trio-preferred-credit-card
#
# Talbots Classic Awards Credit Card
# https://www.cardratings.com/credit-card/talbots-classic-awards-platinum-credit-card.html
#
# Tampa Bay Buccaneers NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/tampa-bay-buccaneers-nfl-extra-points-from-barclays-bank-delaware
#
# Tampa Bay Rays® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/tampa-bay-rays-bankamericard-cash-rewards-mastercard
#
# Taste of Home MasterCard® with Rewards
# https://www.cardratings.com/credit-card/taste-of-home-mastercard-with-rewards-review
#
# Teachers FCU Business Credit Card
# https://www.cardratings.com/credit-card/teachers-fcu-business-credit-card-review
#
# Tennessee Titans NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/tennessee-titans-nfl-extra-points-from-barclays-bank-delaware
#
# Tennis Express Rewards Visa® Credit Card
# https://www.cardratings.com/credit-card/tennis-express-rewards-visa-credit-card-review
#
# Texas Capital Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/texas-capital-bank-cash-rewards-american-express-card-review
#
# Texas Capital Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/texas-capital-bank-premier-rewards-american-express-card-review
#
# Texas Capital Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/texas-capital-bank-secured-visa-card-review
#
# Texas Capital Bank Visa Signature® College Real Rewards Card
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-signature-college-real-rewards-card-review
#
# Texas Capital Bank Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-signature-real-rewards-card-review
#
# Texas Capital Bank Visa® Business Card
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-business-card-review
#
# Texas Capital Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-business-cash-card-review
#
# Texas Capital Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-business-real-rewards-card-review
#
# Texas Capital Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-business-rewards-plus-card-review
#
# Texas Capital Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/texas-capital-bank-visa-platinum-card-review
#
# Texas Rangers® BankAmericard Cash Rewards™ MasterCard®
# https://www.cardratings.com/credit-card/texas-rangers-bankamericard-cash-rewards-mastercard-.html
#
# Texas Tech MasterCard® with Rewards
# https://www.cardratings.com/credit-card/texas-tech-mastercard-with-rewards-review
#
# The Brooks Brothers Card
# https://www.cardratings.com/credit-card/the-brooks-brothers-card-review
#
# The Brooks Brothers Platinum MasterCard®
# https://www.cardratings.com/credit-card/the-brooks-brothers-platinum-mastercard-review
#
# The Container Store® Credit Card
# https://www.cardratings.com/credit-card/the-container-store-credit-card-review
#
# The Linux Foundation Visa® Card
# https://www.cardratings.com/credit-card/the-linux-foundation-visa-platinum-rewards-card
#
# Tioga State Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/tioga-state-bank-cash-rewards-american-express-card-review
#
# Tioga State Bank College Real Rewards Visa® Card
# https://www.cardratings.com/credit-card/tioga-state-bank-college-real-rewards-visa-card
#
# Tioga State Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/tioga-state-bank-premier-rewards-american-express-card-review
#
# Tioga State Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/tioga-state-bank-secured-visa-card
#
# Tioga State Bank Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-signature-real-rewards-card
#
# Tioga State Bank Visa® Business Card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-business-card
#
# Tioga State Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-business-cash-card-review
#
# Tioga State Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-business-real-rewards-card
#
# Tioga State Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-business-rewards-plus-card
#
# Tioga State Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/tioga-state-bank-visa-platinum-card
#
# Tompkins Trust Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/tompkins-trust-company-cash-rewards-american-express-card.html
#
# Unknown
# https://www.cardratings.com/credit-card/
#
# Tompkins Trust Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/tompkins-trust-company-premier-rewards-american-express-card-.html
#
# Tompkins Trust Secured Visa® Card
# https://www.cardratings.com/credit-card/tompkins-trust-secured-visa-card
#
# Tompkins Trust Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/tompkins-trust-company-visa-signature-real-rewards-card
#
# Tompkins Trust Visa® Business Card
# https://www.cardratings.com/credit-card/tompkins-trust-company-visa-business-card
#
# Tompkins Trust Visa® Business Cash Card
# https://www.cardratings.com/credit-card/tompkins-trust-visa-business-cash-card-review
#
# Tompkins Trust Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/tompkins-trust-company-visa-platinum-business-rewards-cards
#
# Tompkins Trust Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/tompkins-trust-company-visa-business-rewards-plus-card
#
# Tompkins Trust Visa® Platinum Card
# https://www.cardratings.com/credit-card/tompkins-trust-company-visaplatinum-card
#
# Toronto Blue Jays® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/toronto-blue-jays-major-league-baseball-extra-bases-credit-card
#
# Torrid Insider Credit Card
# https://www.cardratings.com/credit-card/torrid-insider-credit-card.html
#
# Toyota Rewards Visa Signature® Card
# https://www.cardratings.com/credit-card/toyota-rewards-visa-signature-card--review
#
# Trek Credit Card
# https://www.cardratings.com/credit-card/trek-credit-card.html
#
# Tulsa Alumni Rewards Visa® Card
# https://www.cardratings.com/credit-card/tulsa-alumni-rewards-visa-card-review
# United Club℠ Infinite Card
# https://www.cardratings.com/credit-card/united-club-infinite-card
#
# United℠ Explorer Card
# https://www.cardratings.com/credit-card/united-explorer-card.html
#
# if you are not a devotee of united airlines or you simply don't travel very often, this is probably not the card for you. while there is a $0 annual fee for the first year, it jumps to $95 a year after that.
# U.S. Pride® BankAmericard Cash Rewards™ Visa® Card
# https://www.cardratings.com/credit-card/u.s.-pride-bankamericard-cash-rewards-visa-card.html
#
# UBS Visa Infinite Credit Card
# https://www.cardratings.com/credit-card/ubs-visa-infinite-credit-card
#
# UBS Visa Signature® Credit Card
# https://www.cardratings.com/credit-card/ubs-visa-signature-credit-card
#
# UMB Direct Cash® Visa® Signature Credit Card
# https://www.cardratings.com/credit-card/umb-direct-cash-visa-signature-credit-card-review
#
# UMB Simply Rewards Visa® Platinum Card
# https://www.cardratings.com/credit-card/umb-simply-rewardstm-visa-platinum-credit-card.html
#
# UMSL Alumni Rewards Visa® Card
# https://www.cardratings.com/credit-card/umsl-alumni-rewards-visa-card-review
#
# UNT North Texas Alumni Credit Card with Rewards
# https://www.cardratings.com/credit-card/unt-north-texas-alumni-credit-card-with-rewards-review
#
# US Appliance Credit Card
# https://www.cardratings.com/credit-card/us-appliance-credit-card-review
#
# USA Volleyball Visa Signature® Credit Card
# https://www.cardratings.com/credit-card/usa-volleyball-visa-signature-credit-card-review
#
# USAA Rewards™ Visa Signature® Card
# https://www.cardratings.com/credit-card/usaa-rewards-visa-signature-review
#
# Uber Visa Card
# https://www.cardratings.com/credit-card/uber-visa-credit-card-review
#
# Union Bank Business Rewards Visa® Credit Card
# https://www.cardratings.com/credit-card/union-bank-business-rewards-visa-credit-card-review
#
# Union Bank Business Secured Visa® Credit Card
# https://www.cardratings.com/credit-card/union-bank-business-secured-visa-credit-card-review
#
# Union Bank Business Visa® Credit Card
# https://www.cardratings.com/credit-card/union-bank-business-visa-credit-card-review
#
# Union Bank Cashback Rewards Visa® Card
# https://www.cardratings.com/credit-card/union-bank-cashback-rewards-visa-card-review
#
# Union Bank Rewards Visa® Card
# https://www.cardratings.com/credit-card/union-bank-rewards-visa-card-review
#
# Union Bank Secured Visa® Credit Card
# https://www.cardratings.com/credit-card/union-bank-secured-visa-credit-card-review
#
# Union Bank Travel Rewards Visa® Card
# https://www.cardratings.com/credit-card/union-bank-travel-rewards-visa-card-review
#
# Union Bank Visa® Credit Card
# https://www.cardratings.com/credit-card/union-bank-visa-credit-card-review
#
# United Nations Federal Credit Union Azure Credit Card
# https://www.cardratings.com/credit-card/unfcu-visa-azure-credit-card.html
#
# United Nations Federal Credit Union Elite Credit Card
# https://www.cardratings.com/credit-card/united-nations-federal-credit-union-elite-credit-card
#
# University of Montana Visa® Rewards Credit Card
# https://www.cardratings.com/credit-card/montana-visa-rewards-credit-card-review
#
# Upromise MasterCard®
# https://www.cardratings.com/credit-card/upromise-mastercard.html
#
# Valparaiso Alumni Visa® Rewards Card
# https://www.cardratings.com/credit-card/valparaiso-alumni-visa-rewards-card-review
#
# Value City Furniture® Credit Card
# https://www.cardratings.com/credit-card/value-city-furniture-credit-card-review
#
# Victoria's Secret Angel Credit Card
# https://www.cardratings.com/credit-card/victorias-secret-angel-credit-card
#
# Virgin Atlantic World Elite MasterCard®
# https://www.cardratings.com/credit-card/virgin-atlantic-world-elite-mastercard.html
#
# Washington Nationals® BankAmericard Cash Rewards MasterCard®
# https://www.cardratings.com/credit-card/washington-nationals-bankamericard-cash-rewards-mastercard
#
# Washington Redskins NFL Extra Points Visa Signature Card
# https://www.cardratings.com/credit-card/washington-redskins-nfl-extra-points-from-barclays-bank-delaware
#
# Webster Bank Cash Rewards American Express® Card
# https://www.cardratings.com/credit-card/webster-bank-cash-rewards-american-express-card-review
#
# Webster Bank Premier Rewards American Express® Card
# https://www.cardratings.com/credit-card/webster-bank-premier-rewards-american-express-card-review
#
# Webster Bank Secured Visa® Card
# https://www.cardratings.com/credit-card/webster-bank-secured-visa-card-review
#
# Webster Bank Visa Signature® College Real Rewards Card
# https://www.cardratings.com/credit-card/webster-bank-visa-signature-college-real-rewards-card-review
#
# Webster Bank Visa Signature® Real Rewards Card
# https://www.cardratings.com/credit-card/webster-bank-visa-signature-real-rewards-card-review
#
# Webster Bank Visa® Business Cash Card
# https://www.cardratings.com/credit-card/webster-bank-visa-business-cash-card-review
#
# Webster Bank Visa® Business Platinum Card
# https://www.cardratings.com/credit-card/webster-bank-visa-business-platinum-card-review
#
# Webster Bank Visa® Business Real Rewards Card
# https://www.cardratings.com/credit-card/webster-bank-visa-business-real-rewards-card-review
#
# Webster Bank Visa® Business Rewards PLUS Card
# https://www.cardratings.com/credit-card/webster-bank-visa-business-rewards-plus-card-review
#
# Webster Bank Visa® Platinum Card
# https://www.cardratings.com/credit-card/webster-bank-visa-platinum-card-review
#
# Wells Fargo Advisors By Invitation® Visa Signature ® Card
# https://www.cardratings.com/credit-card/wells-fargo-advisors-by-invitation-visa-signature-card.html
#
# Wells Fargo Business Elite Card
# https://www.cardratings.com/credit-card/wells-fargo-business-elite-card
#
# Wells Fargo Business Platinum Credit Card
# https://www.cardratings.com/credit-card/wells-fargo-business-platinum-credit-card
#
# Wells Fargo Business Secured Credit Card
# https://www.cardratings.com/credit-card/wells-fargo-business-secured-credit-card--review
#
# Wells Fargo Cash Back College Visa® Card
# https://www.cardratings.com/credit-card/wells-fargo-cash-back-sm-college-card
#
# Wells Fargo Visa Signature® Card
# https://www.cardratings.com/credit-card/wells-fargo-visa-signature-card.html
#
# WestJet RBC MasterCard
# https://www.cardratings.com/credit-card/westjet-rbc-mastercard.html
#
# WestJet RBC® World Elite MasterCard‡
# https://www.cardratings.com/credit-card/westjet-rbc-world-elite-mastercard.html
#
# Whitetails Unlimited Visa® Rewards Card
# https://www.cardratings.com/credit-card/whitetails-unlimited-visa-rewards-card-review
#
# World Wildlife Fund Visa Card
# https://www.cardratings.com/credit-card/world-wildlife-fund-visa-card.html
#
# Wyndham Rewards® Visa Signature® Card (Annual Fee)
# https://www.cardratings.com/credit-card/wyndham-rewards-visa-signature-card
#
# Wyndham Rewards® Visa Signature® Card (No Annual Fee)
# https://www.cardratings.com/credit-card/wyndham-rewards-visa-signature-no-annual-fee-card
#
# Zions Bank AmaZing Cash® Credit Card
# https://www.cardratings.com/credit-card/zions-bank-amazing-cash-credit-card
#
# Zions Bank AmaZing Cash™ for Business Credit Card
# https://www.cardratings.com/credit-card/zions-bank-amazing-cash-for-business.html
#
# Zions Bank AmaZing Rate® for Business
# https://www.cardratings.com/credit-card/amazing-rate-for-business.html
#
# Zions Bank AmaZing Rate™ Low Rate Credit Card
# https://www.cardratings.com/credit-card/zions-bank-amazing-rate-low-rate-credit-card
#
# Zions Bank AmaZing Rewards® Credit Card
# https://www.cardratings.com/credit-card/zions-bank-amazing-rewards-credit-card
#
# Zions Bank AmaZing Rewards® for Business
# https://www.cardratings.com/credit-card/amazing-rewards-for-business.html

# %%
db = pd.DataFrame(database)
db.set_index('name', inplace=True)

# %%
with open('../database.pkl', 'wb') as f:
    pickle.dump(db, f)

# %%
assert False

# %%
    
def get_annual_bonus(string):
    """
    A function to look through a string and try and find the annual 
    bonuses that you get with a particular card that offsets the annual
    fee of those cards
    
    Inputs:
    - string (str), a string that contians a description of the card bonuses
    
    Outputs:
    - credits (float), the dollar amount of the annual bonus
    """
    credits = 0
    for line in string.split('\n'):
        credit_words = ['saving', 'credits'] # we want to see these words in a sentence
        comparitive_words = ['higher', 'lower', 'worse', 'better'] # we don't want to see these words
        if any(map(lambda x: x in line.lower(), credit_words)) and not any(map(lambda x: x in line, comparitive_words)):
            try:
                credits += max([float(credit[1:]) for credit in re.findall('\$\d+', line) if float(credit[1:]) >= 50])
            except ValueError:
                pass
    return credits

def get_rewards_info_from_url(url):
    """
    A function that will request the html data from a url and find
    the rewards, annual fee, and annual bonuses for that link. This
    function isn't 100% working (issues with annual fee and bonus). But
    can parse out the rewards.
    
    Inputs:
    - url (str), a string representation of the url
    
    Outputs:
    - title (str), the title of the post
    - rewards (dict), a dictionary containing the rewards, annual_fee
        annual_bonus, and net_fee
    """
    
    print()
    print()
    res = requests.get(url)
    html_page = res.content
    soup = BeautifulSoup(html_page, 'html.parser')
    title = soup.title.text
    print(title)
    print(url)
    if '400' in title:
        rewards = {
            'flights':0,
            'hotel':0,
            'grocery':0,
            'gas':0,
            'utilities':0,
            'restaurants':0,
            'other':0 
        }
        rewards['annual_fee'] = 0
        rewards['annual_bonus'] = 0
        rewards['net_fee'] = 0
        print(rewards)
        return None, rewards
        
    d = soup.find('div', itemprop='description')
    try:
        df = pd.read_html(d.decode())[0].T.set_index(0)
    except:
        rewards = {
            'flights':0,
            'hotel':0,
            'grocery':0,
            'gas':0,
            'utilities':0,
            'restaurants':0,
            'other':0 
        }
        rewards['annual_fee'] = 0
        rewards['annual_bonus'] = 0
        rewards['net_fee'] = 0
        print(rewards)
        return title, rewards
        
        
    if 'Rewards' in df.index:
        rewards = get_rewards_from_string(df[1]['Rewards'])
        try:
            rewards['annual_fee'] = get_annual_fee(df[1]['Annual Fee'])
        except KeyError:
            rewards['annual_fee'] = 0
            for line in d.text.split('\n'):
                if 'annual fee' in line.lower():
                    rewards['annual_fee'] = get_annual_fee(line)
                    break
            
            
        rewards['annual_bonus'] = get_annual_bonus(d.text)
        rewards['net_fee'] = rewards['annual_fee'] - rewards['annual_bonus']
    else:
        rewards = get_rewards_from_string(d.text)
        rewards['annual_fee'] = 0
        rewards['annual_bonus'] = 0
        rewards['net_fee'] = 0
    print(rewards)
    return title, rewards

# %%
# A list of keywords we're looking for 
KEY_WORDS = {
    'flights':['flights', 'airlines','travel', 'air', 'southwest', 'fly'],
    'hotel': ['travel', 'hotel'] ,
    'grocery':['supermarket', 'grocery', 'groceries'],
    'gas':['station', 'gas'],
    'utilities':['telephone', 'shipping', 'internet', 'cabel'],
    'restaurants':['restaurants', 'dining'],
    'other':['select', 'rotating']
}



def fix_flat_cash_back(rewards_dict, categories):
    """Helper function to fix cards that have 1.5 cash back on everything"""
    for category in categories:
        rewards_dict[category] = 1.5
    return rewards_dict










def get_annual_fee(soup):
    def monetize(string):
        try:
            return float(re.search('\$\d+', string).group()[1:])
        except AttributeError:
            return 0.
    df = get_df_from_tag(soup)
    if df is not None and 'Annual Fee' in df.index:
        try:
            fee = monetize(df.loc['Annual Fee'][1])
        except ValueError:
            return 0.0
    fee = 0
    found_one  = False
    for tag in soup.find_all('div', attrs={'itemprop':'description'}):
        for sentence in tag.text.split('\n'):
            for annual_fee_to_remove in NO_ANNUAL_FEE_TO_REMOVE:
                sentence = sentence.lower().replace(annual_fee_to_remove, '')
            if found_one: continue
            if 'annual fee ' in sentence:
                print(sentence)
                found_one = True
                fee = monetize(sentence)
    if not found_one:
        return 0
    return fee

# %%
int_results = []
import random

for url in cc_urls[:100]:
    r = {}
    print(url)
    soup = make_soup(url)
    r['name'] = find_card_name(soup)
    r['card_type'] = get_card_type(r['name'])
    
    r['req_credit'] = find_req_credit(soup)
    all_15 = False
    for category, key_words in KEY_WORDS.items():
        reward = get_rewards_from_soup(soup, category, key_words)
        if reward == 1.5:
            all_15 = True
        r[category] = get_rewards_from_soup(soup, category, key_words)

    if all_15: 
        r = fix_flat_cash_back(r, KEY_WORDS.keys())
    r['rotating'] = find_rotating(soup)
    r['annual_fee'] = get_annual_fee(soup)
    r['review'] = url
    r['app_link'] = get_application_link(soup)
    int_results.append(r)

# %%
soup = make_soup('https://www.cardratings.com/credit-card/discover-it-cash-back.html')

def get_info_dict(soup):
    tables = soup.find_all('div', attrs={'id':'top_features_box'})
    table_info = {}
    for table in tables:
        for entry in table.find_all('div', attrs={'class':'col-12 px-5 mt-4'}):
            table_info[entry.find('div', attrs={'class':'gridTitle'}).text.lstrip('\n\xa0')] = \
                entry.find('div', attrs={'class':'mt-1'}).text
    return table_info


KEY_WORDS = {
    'flights':['flights', 'airlines','travel', 'air', 'southwest', 'fly'],
    'hotel': ['travel', 'hotel'] ,
    'grocery':['supermarket', 'grocery', 'groceries'],
    'gas':['station', 'gas'],
    #'utilities':['telephone', 'shipping', 'internet', 'cabel'],
    'dining':['restaurants', 'dining'],
    'other':['select', 'rotating']
}

def get_rewards_from_string(string, category, key_words):
    """Get rewards specific for a category with given keywords """
    if not isinstance(string, str):
        return 0.0

    for sentence in string.replace('U.S.', 'US').split('. '):
        if any(map(lambda x: x in sentence.lower(), key_words)):
            try:
                multiplyer = float(re.search('(\d+(?:\.\d+)?)', sentence).group())
                if multiplyer > 15:
                    continue
                return multiplyer
            except AttributeError:
                continue

    return 0.0

TYPE1_KEYS = sorted(['Rewards', 'Bonus Rewards', 'Annual Fee'])
TYPE2_KEYS = sorted(['Cash Back on Gas', 'Cash Back on Groceries', 'Cash Back on Other'])

def clean_rewards_dict(rewards):
    if not (np.array(list(r.values())) >= 1).any():
        return rewards
    
    for key, value in rewards.items():
        if value == 0:
            rewards[key] = 1.0
    return rewards



def get_reward_points_from_dict(table_info):
    rewards = {}
    for key in KEY_WORDS.keys():
        rewards[key] = 0.0
    if TYPE1_KEYS == sorted(list(table_info.keys())):
        string = table_info['Rewards']
        for category, key_words in KEY_WORDS.items():
            rewards[category] = get_rewards_from_string(string, category, key_words)

    elif TYPE2_KEYS == sorted(list(table_info.keys())):
        for category, key in zip(['gas', 'grocery', 'other'], TYPE2_KEYS):
            try:
                info = table_info[key]
                info = info.split('%')[0]
                if '-' in info:
                    point_value = max([float(i) for i in info.split('-')])
                else:
                    point_value = float(info)
            except:
                point_value = 0
                
            rewards[category] = point_value
    
    rewards = clean_rewards_dict(rewards)
    return rewards


def

r

# %%
soup = make_soup('https://www.cardratings.com/credit-card/discover-it-cash-back.html')
tables = soup.find_all('div', attrs={'id':'top_features_box'})
table_info = {}
for table in tables:
    for entry in table.find_all('div', attrs={'class':'col-12 px-5 mt-4'}):
        table_info[entry.find('div', attrs={'class':'gridTitle'}).text.lstrip('\n\xa0')] = \
            entry.find('div', attrs={'class':'mt-1'}).text
table_info

# %%
def get_df_from_tag(tag):
    """Helps us find this 'rewards table' that exists in many pages """
    try:
        table = tag.find('table', attrs={'class': 'primaryCatgrid'})
        return pd.read_html(table.decode())[0].T.set_index(0)
    except:
        return None


def get_rewards_from_string(string, category, key_words):
    """Get rewards specific for a category with given keywords """
    if not isinstance(string, str):
        return 0.0

    for sentence in string.replace('U.S.', 'US').split('. '):
        if any(map(lambda x: x in sentence.lower(), key_words)):
            try:
                multiplyer = float(re.search('(\d+(?:\.\d+)?)', sentence).group())
                if multiplyer > 15:
                    continue
                return multiplyer
            except AttributeError:
                continue

    return 0.0

def get_rewards_from_df(df, category, key_words):
    """Use a few of the above functions to find rewards"""
    if 'Rewards' in df.index:
        return get_rewards_from_string(df[1]['Rewards'], category, key_words)
    else:
        return None

# %%
for tag in soup.find_all('div', attrs={'itemprop':'description'}):
    for paragraph in tag.find_all('p'):
        if 'annual fee' in paragraph.text.lower().replace('no annual fee', ''):
            print(paragraph.text)
            print()

# %%
all_rewards_df = pd.DataFrame(int_results)
all_rewards_df

# %%
for tag in soup.find_all('div', attrs={'itemprop':'description'}):
    for sentence in tag.text.split('\n'):
        if 'annual fee' in sentence.lower().replace('no annual fee', ''):
            print(sentence)

# %%
if True: #not os.path.exists('rewards.pkl'): 
    # If we've run this before, we're gonna read in a pickle file
    # to save time
    total_rewards = {}
    for cc_url in cc_urls:
        if cc_url == "https://www.cardratings.com/credit-card/connect-classic":
            continue # known to be broken url
        title, rewards = get_rewards_info_from_url(cc_url)
        if title: # cleaning up the title
            title_string = ''
            review = False
            for t in title.split():
                if '-' in t.lower() or 'review' in t.lower():
                    break
                title_string += t + ' '
            total_rewards[title_string.strip()] = rewards

    # Making and saving the dataframe
    rewards_df = pd.DataFrame(total_rewards).T
    f = open('rewards.pkl', 'wb')
    pickle.dump(rewards_df, f)
else:
    print('Reading results from a previous pickle file')
    f = open('rewards.pkl', 'rb')
    rewards_df = pickle.load(f)
    
    
rewards_df

# %%
rewards_df.loc['ABOC Platinum Rewards Mastercard® Credit Card']

# %%
# Currently don't trust the annual fee and bonus section, 
# so we're going to process based on the rewards alone

# TODO: Find accurate net_fee for all cards and use that when 
# calculating rewards
to_plot = rewards_df[rewards_df.columns[:-3]]

# Only looking at credit card with greater than 1% back at everything
to_plot = to_plot[to_plot.sum(axis=1) > len(to_plot.columns)]

# Removing cards that have a weirdly high point value
# These data are either parsed incorrectly or are hotel rewards were
# the point to cent ratio is high (e.g. many points to a cent)
to_plot = to_plot[to_plot.sum(axis=1) <= 2*len(to_plot.columns)] 
to_plot

# %%
# From my own annual expenses over the last 12 months

# Reading in a CSV file from my mint.com accout
transactions = pd.read_csv('transactions-3.csv')
transactions['Date'][0]
def compare_date(date):
    """
    A function to find if a date is within a year from now
    
    Inputs:
    - date (str), a date in the mm/dd/yyyy format
    
    Returns:
    - bool (str), a bool indicating if the date is 
        within a year from now or not
    """
    other = '4/3/2020'
    m,d,y = date.split('/')
    om,od,oy = other.split('/')
    m = int(m)
    d = int(d)
    y = int(y)
    om = int(om)
    od = int(od)
    oy = int(oy)
    if oy <= y+1:
        if om < m:
            return True
        elif om == m:
            if od < d:
                return True
            else:
                return False
        else: 
            return False
    else:
        return False
# Removing all positive transactions
transactions = transactions[transactions['Transaction Type'] == 'debit']

# Finding all transactions within a year of now
transactions = transactions[transactions['Date'].map(compare_date)]

# Parsing out annual expenses for each specific category
food = transactions[transactions.Category.map(lambda x: x.lower() in ['food & dinging', 'alcohol & bars', 'restaurants', 'fast food'])].Amount.sum()
flights = transactions[transactions.Category.map(lambda x: x.lower() in ['air travel'])].Amount.sum()
hotel = transactions[transactions.Category.map(lambda x: x.lower() in ['hotel'])].Amount.sum()
gas = transactions[transactions.Category.map(lambda x: x.lower() in ['auto & transport', 'gas & fuel'])].Amount.sum()
grocery = transactions[transactions.Category.map(lambda x: x.lower() in ['groceries'])].Amount.sum()
utilities = transactions[transactions.Category.map(lambda x: x.lower() in ['bills & utilities', 'mobile phone', 'internet'])].Amount.sum()
other = transactions.Amount.sum() - food -  flights - hotel - gas - grocery

# Making a dict containing all of the expenses, to be used later
expenses = {
    'flights': flights,
    'hotel':hotel,
    'grocery':grocery,
    'gas':gas,
    'restaurants': food,
    'other':other
    
}

expenses

# %%
def calculate_rewards(rewards_df, expenses):
    """
    A function to calculate the max rewards for a parsed dataframe.
    TODO: this needs to eventually include net_fee in it's equation.
    
    Inputs:
    - rewards_df (pd.DateFrame), a sliced dataframe with columns
        similar to to_plot
    - expenses (dict), a dictionary containing all of a person's 
        annual expenses
        
    Returns:
    - cash_rewards (float), the annual rewards one would recieve
    """
    cash_rewards = 0
    for category, expense in expenses.items():
        try:
            if isinstance(rewards_df[category], float):
                rate = rewards_df[category] / 100
            else:
                rate = max(rewards_df[category]) / 100
            cash_rewards += rate * expense
        except:
            continue
        
    return cash_rewards - rewards_df['annual_fee'].sum() + rewards_df['annual_bonus'].sum()

# %%
# Given that there are many different combinations of cards, we're 
# going to be solving this stochasticly. 1000 random combination of
# `card_number` of cards will be chosen and will be used to estimate 
# annual rewards. These will be stored to find an approximate max, median
# and min amount of rewards for each number_of_cards.

if False:#os.path.exists('calculated_rewards.pkl') and os.path.exists('cloud.pkl'):
    f = open('calculated_rewards.pkl', 'rb')
    calculated_rewards = pickle.load(f)
    f = open('cloud.pkl', 'rb')
    word_cloud = pickle.load(f)
else:
    calculated_rewards = {} # to keep track of total rewards
    word_cloud = {} # to be used for a wordcloud
    for card_number in range(11):
        # Between 0 and 10 cards
        card_rewards = []
        cloud_list = []

        for i in range(5000):
            choice = np.random.choice(db.index, card_number)
            card_rewards.append(calculate_rewards(db.loc[choice], expenses))
            cloud_list.append((calculate_rewards(db.loc[choice], expenses), choice))
            
        calculated_rewards[card_number] = card_rewards
        word_cloud[card_number] = cloud_list

    f = open('calculated_rewards.pkl', 'wb')
    pickle.dump(calculated_rewards, f)
    f = open('cloud.pkl', 'wb')
    pickle.dump(word_cloud, f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#from scipy.interpolate import interp1d
sns.set()
mins = []
medians = []
maxes = []
for card_number, rewards in calculated_rewards.items():
    # For `card_number` number of credit cards ...
    mins.append(np.min(rewards)) # ... the min rewards 
    maxes.append(np.max(rewards)) # ... the max rewards
    medians.append(np.median(rewards)) # ... the median rewards

fig, ax = plt.subplots(figsize=(12,8))

ax.scatter(calculated_rewards.keys(), medians, label='Median')

smooth_median = max(medians)
smooth_number_of_cards = np.linspace(min(calculated_rewards.keys()), max(calculated_rewards.keys()), 500)  

# Smoothing the curve for min rewards 
power_smooth = interp1d(list(calculated_rewards.keys()), mins, kind='cubic')
smooth_min = max(power_smooth(smooth_number_of_cards)) # the limit
ax.plot(smooth_number_of_cards, power_smooth(smooth_number_of_cards), '-', c='g', linewidth=5, label='Maximum / Minimum')

# Smoothing the curve for max rewards
power_smooth = interp1d(list(calculated_rewards.keys()), maxes, kind='cubic')
smooth_max = max(power_smooth(smooth_number_of_cards)) # the limit
ax.plot(smooth_number_of_cards, power_smooth(smooth_number_of_cards), '-', c='g', linewidth=5)




# Plotting lines for the limits of the max, median, and min
ax.plot([0,10], [smooth_min, smooth_min], alpha=0.5, c='k', linewidth=3, label='Plateaus')
ax.plot([0,10], [smooth_max, smooth_max], alpha=0.5, c='k', linewidth=3)
ax.plot([0,10], [smooth_median, smooth_median], alpha=0.5, c='k', linewidth=3)
ax.annotate(f'Max plateau at ~${int(round(smooth_max,-1))}', xy=(6, smooth_max),  xycoords='data',
            xytext=(0.8, 0.5), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='top',
            )
ax.annotate(f'Min plateau at ~${int(round(smooth_min,-1))}', xy=(2, smooth_min),  xycoords='data',
            xytext=(0.5, 0.3), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='top',
            )

ax.annotate(f'Median plateau at ~${int(round(smooth_median,-1))}', xy=(4.5, smooth_median),  xycoords='data',
            xytext=(0.7, 0.4), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='top',
            )

#ax.set_yscale('log', nonposy='clip')
ax.legend()
ax.set_xticks(range(11))
ax.set_ylabel('Annual Rewards (\$)')
ax.set_xlabel('Number of Credit Cards')
ax.set_title('Calculated rewards for various numbers of credit cards for Nate\'s expenses')

# %%
fig.savefig('trends.pdf')#, bbox_inches='tight')

# %%
sns.boxenplot(data=pd.DataFrame(calculated_rewards))

# %%
sns.violinplot??

# %%
pd.DataFrame(calculated_rewards)
